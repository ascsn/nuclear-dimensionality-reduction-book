# %%
import numpy as np
from scipy import optimize
import os
import subprocess
from contextlib import contextmanager
import time
import matplotlib.pyplot as plt
import math
from multiprocess import Pool
import random
import json

# %% [markdown]
# First, we'll read in the files created by the Fortran HF code. Things are a little messy thanks to the way I stored things in the past, but they are standard numpy arrays after this cell. Take note of the ordering and suggest a more agreeable choice if you've got an opinion.

# %%
@contextmanager
def cwd(path):
    oldpwd=os.getcwd()
    os.chdir(path)
    try:
        yield
    finally:
        os.chdir(oldpwd)

def spin(spin):
    if(spin==1): return -0.5
    return 0.5

def make_input(params,restart,directory):
    in_template = "../HF/in.template"
    f1 = open(in_template, 'r')
    
    int_string = "&interaction t0={t0},x0={x0},t1={t1},x1={x1},t2={t2},x2={x2},t3={t3},x3={x3},w0={w0},sig={sig},icoul=1,icm=1,j2terms=.true. / \n".format(\
    t0=params["t0"],x0=params["x0"],t1=params["t1"],x1=params["x1"],t2=params["t2"],x2=params["x2"],t3=params["t3"],x3=params["x3"],w0=params["w0"],sig=params["sig"])
    if(restart):
        io_string = "&io printwf=F,printdens=F,restartwf=T,printhpsi=T /"
    else:
        io_string = "&io printwf=T,printdens=F,restartwf=F,printhpsi=F /"
    in_out = directory+"/in"
    f2 = open(in_out, 'w')
    f1.seek(0)
    f2.write(f1.read())
    f2.write(int_string)
    f2.write(io_string)
    f2.write("\n")

    f1.close()
    f2.close()

    return

def run_HF(tag,restart):
    noNaN = 1
    neut = 0
    if(restart == 0):
        os.system("cp in results/in."+tag)
        #print(os.system("../HF/./main"))
        output = subprocess.run(["./main"], capture_output=True)
        #print(output)
        #print(subprocess.run("../HF/./main",shell=True))
        os.system("mv out results/out."+tag)
        os.system("mv wf_numpy.bin results/wf_numpy.bin."+tag)
        noNaN = os.system("grep -q NaN results/out."+tag)
        neut = os.system('grep -q "Total Neutrons =   28.000" results/out.'+tag)
        neut = neut+os.system('grep -q "Total Neutrons =   27.999" results/out.'+tag)
    else:
        output = subprocess.run(["./main"], capture_output=True)
        #os.system("mv out results/out_rst."+tag)
        #os.system("mv hpsi.bin results/hpsi.bin."+tag)
        #print(output)
        #noNaN = os.system("grep -q NaN results/out_rst."+tag)
    if (noNaN == 0):
        print("NaNs in run {tag}!".format(tag=tag))
        return 1
    if(neut > 256):
        print("Wrong number of neutrons in run {tag}!".format(tag=tag))
        return 1

    return 0


def read_wfs(restartfile):
    #restartfile = '../HF/wf_numpy.bin'

    intchunk = np.dtype(np.int32).itemsize
    realchunk = np.dtype(np.float64).itemsize
    h = np.fromfile(restartfile, dtype=np.float64, count=1, offset=0)[0]
    nbox = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(realchunk+0*intchunk))[0]
    lmax = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(realchunk+1*intchunk))[0]
    nmax = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(realchunk+2*intchunk))[0]
#     print("hbox = ", h)
#     print("nbox = ",nbox)
#     print("lmax = ",lmax)
#     print("nmax = ",nmax)

    #sortstates, sortenergies, wfr,
    sortstates = np.fromfile(restartfile, dtype=np.int32, count=nmax*3*2, offset=(realchunk+3*intchunk)).reshape(2,3,nmax)
    sortenergies = np.fromfile(restartfile, dtype=np.float64, count=nmax*2, offset=(realchunk+3*intchunk+nmax*3*2*intchunk)).reshape(2,nmax)
    wfs = np.fromfile(restartfile, dtype=np.float64, count=2*2*(lmax+1)*lmax*(nbox+1), offset=(realchunk+3*intchunk+nmax*3*2*intchunk+sortenergies.nbytes)).reshape(2,2,(lmax+1),lmax,(nbox+1))

    return h,nbox,lmax,nmax,sortstates,sortenergies,wfs

def print_wfs(restartfile,h,nbox,lmax,nmax,sortstates,sortenergies,wfs):
    with open(restartfile, 'wb') as file:
        file.write(h)
        file.write(nbox)
        file.write(lmax)
        file.write(nmax)
        file.write(sortstates.reshape((nmax*3*2,)))
        file.write(sortenergies.reshape((nmax*2,)))
        file.write(wfs.reshape((2*2*(lmax+1)*lmax*(nbox+1),)))

    return

def read_hpsi(restartfile):

    intchunk = np.dtype(np.int32).itemsize

    nbox = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(0*intchunk))[0]
    lmax = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(1*intchunk))[0]
    nmax = np.fromfile(restartfile, dtype=np.int32, count=1, offset=(2*intchunk))[0]

    sortenergies = np.fromfile(restartfile, dtype=np.float64, count=nmax*2, offset=(3*intchunk)).reshape(2,nmax)
    hpsi = np.fromfile(restartfile, dtype=np.float64, count=2*2*(lmax+1)*lmax*(nbox+1), offset=(3*intchunk+sortenergies.nbytes)).reshape(2,2,(lmax+1),lmax,(nbox+1))

    return sortenergies,hpsi

def get_hpsi(params,h,nbox,lmax,nmax,sortstates,sortenergies,wf,directory):
    restartfile = directory+'/wf_numpy.bin'
    print_wfs(restartfile,h,nbox,lmax,nmax,sortstates,sortenergies,wf)

    make_input(params,1,directory)
    #with cwd('../HF/'):
    oldpwd=os.getcwd()

    os.chdir(directory)

    errors.append(run_HF("None",1))
    os.chdir(oldpwd)

    restartfile = directory+'/hpsi.bin'
    sortenergies,hpsi = read_hpsi(restartfile)

    return hpsi

def make_wf(coeffs,train_wfs,states,levels):
    train_num = len(train_wfs)
    tot_levels = sum(levels)
    trial_wf = np.zeros(train_wfs[0].shape)
    for i in range(train_num):
        for isospin in range(2):
            for j in range(levels[isospin]):
                i_s = states[isospin,2,j]-1
                i_l = states[isospin,1,j]
                i_n = states[isospin,0,j]-1
                trial_wf[isospin,i_s,i_l,i_n,:] = trial_wf[isospin,i_s,i_l,i_n,:] \
                    + train_wfs[i][isospin,i_s,i_l,i_n,:] * coeffs[i*tot_levels + isospin*levels[0] + j]
    return trial_wf

def galerkin(coeffs,train_wfs,states,levels,params,directory):
    
    global count
    global prev_time
    
    count += 1
    print("Iteration {}".format(count))
    print("Iteration time: {}".format(time.time() - prev_time))
    
    prev_time = time.time()
    
    results = np.zeros(coeffs.shape)
    
    train_num = len(train_wfs)
    tot_levels = sum(levels)
    
    trial_wf = make_wf(coeffs,train_wfs,states,levels)

    hpsi = get_hpsi(params,h,nbox,lmax,nmax,states,sortenergies,trial_wf,directory)
    #hpsi = compute_hpsi(params,h,nbox,lmax,nmax,sortstates,sortenergies,trial_wf)
    for i in range(train_num):
        for isospin in range(2):
            for j in range(levels[isospin]):
                i_s = states[isospin,2,j]-1
                i_l = states[isospin,1,j]
                i_n = states[isospin,0,j]-1
                ele = i*tot_levels + isospin*levels[0] + j
                lam = coeffs[train_num*tot_levels + isospin*levels[0] + j]
                results[ele] = h*np.dot(train_wfs[i][isospin,i_s,i_l,i_n,:],hpsi[isospin,i_s,i_l,i_n,:]) \
                    - lam*h*np.dot(train_wfs[i][isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])


    for isospin in range(2):
        for j in range(levels[isospin]):
            i_s = states[isospin,2,j]-1
            i_l = states[isospin,1,j]
            i_n = states[isospin,0,j]-1
            ele = train_num*tot_levels + isospin*levels[0] + j
            results[ele] = h*np.dot(trial_wf[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:]) - 1.0
    if(count%100 == 0):print(results)
    if(count%100 == 0):print(coeffs)
            
    return results

def galerkin_min(coeffs,train_wfs,states,levels,params,directory):
    
    #global count
    #global prev_time
    
    #count += 1
    #print("Iteration {}".format(count))
    #print("Iteration time: {}".format(time.time() - prev_time))
    
    #prev_time = time.time()
    
    results = np.zeros(coeffs.shape)
    
    train_num = len(train_wfs)
    tot_levels = sum(levels)
    
    trial_wf = make_wf(coeffs,train_wfs,states,levels)

    hpsi = get_hpsi(params,h,nbox,lmax,nmax,states,sortenergies,trial_wf,directory)
    #hpsi = compute_hpsi(params,h,nbox,lmax,nmax,sortstates,sortenergies,trial_wf)
    for i in range(train_num):
        for isospin in range(2):
            for j in range(levels[isospin]):
                i_s = states[isospin,2,j]-1
                i_l = states[isospin,1,j]
                i_n = states[isospin,0,j]-1
                ele = i*tot_levels + isospin*levels[0] + j
                lam = coeffs[train_num*tot_levels + isospin*levels[0] + j]
                results[ele] = h*np.dot(train_wfs[i][isospin,i_s,i_l,i_n,:],hpsi[isospin,i_s,i_l,i_n,:]) \
                    - lam*h*np.dot(train_wfs[i][isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])


    for isospin in range(2):
        for j in range(levels[isospin]):
            i_s = states[isospin,2,j]-1
            i_l = states[isospin,1,j]
            i_n = states[isospin,0,j]-1
            ele = train_num*tot_levels + isospin*levels[0] + j
            results[ele] = h*np.dot(trial_wf[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:]) - 1.0
    #if(count%100 == 0):print(results)
            
    return np.sum(results[:]**2)

def galerkin_wrapper(coeffs,train_wfs,sortstates,levels,params,directory):
    hybr_dict = {'col_deriv': 0, 'xtol': 1.49012e-25,'maxfev': 10000, 'band': None, 'eps': None, 'factor': 100, 'diag': None}
    sol = optimize.root(galerkin, coeffs, args=(train_wfs,sortstates,levels,params,directory), method='hybr', options=hybr_dict)
    return sol
def galerkin_wrapper_min(coeffs,train_wfs,sortstates,levels,params,directory):
    #Powell
    min_dict = {'xtol': 0.0001, 'ftol': 0.0001, 'maxiter': None, 'maxfev': 5000, 'disp': True, 'direc': None, 'return_all': False}
    sol = optimize.minimize(galerkin_min, coeffs, args=(train_wfs,sortstates,levels,params,directory), method='powell', options=min_dict)
    return sol

def hf_wrapper(params,directory):
    make_input(params,0,directory)
    with cwd(directory):
        run_HF("test",0)
    return

def compute_hpsi(params,h,nbox,lmax,nmax,sortstates,sortenergies,wf):
    mesh = np.linspace(0, 20, nbox+1)
    mesh[0] = 1e-25
    t0 = params["t0"]
    t1 = params["t1"]
    t2 = params["t2"]
    t3 = params["t3"]
    x0 = params["x0"]
    x1 = params["x1"]
    x2 = params["x2"]
    x3 = params["x3"]
    w0 = params["w0"]
    sig = params["sig"]
    sig = 1.0/sig
    e2 = 1.4399784
    pi = 3.141592653589793
    hbar = 6.582119e-22
    hbar22m=20.73553
    A = 48.0
    cmcorr = 1.0 - (1.0/A)
    a0r0 = 3.0/8.0 * t0
    a1r1 = - 1.0/4.0 * t0 * ( 1.0/2.0 + x0 )
    a0s0 = - 1.0/4.0 * t0 * ( 1.0/2.0 - x0 )
    a1s1 = - 1.0/8.0 * t0
    
    a0tau0 = 3.0/16.0 * t1 + 1.0/4.0 * t2 * ( 5.0/4.0 + x2 )
    a1tau1 = - 1.0/8.0 * t1 * ( 1.0/2.0 + x1 ) + \
            1.0/8.0 * t2 * ( 1.0/2.0 + x2 )
    
    a0t0 = - 1.0/8.0 *t1* ( 1.0/2.0 - x1 ) + \
            1.0/8.0 * t2 * ( 1.0/2.0 + x2 )
    a1t1 =  1.0/16.0 * (t2-t1)
    
    a0r0p = - 9.0/64.0 * t1 + 1.0/16.0 * t2 *( 5.0/4.0 + x2 )
    a1r1p = 3.0/32.0 * t1 * ( 1.0/2.0 + x1 ) + \
            1.0/32.0 * t2 * ( 1.0/2.0 + x2 )

    a0s0p = 3.0/32.0 * t1 * ( 1.0/2.0 - x1 ) + \
            1.0/32.0 * t2 * ( 1.0/2.0 + x2 )
    a1s1p = 3.0/64.0 * t1 + 1.0/64.0 * t2
    
    cddr0 =  t3 / 16.00
    cddr1 = - 1.0/24.0 * t3 * ( 1.0/2.0 + x3 )
    cdds0 = - 1.0/24.0 * t3 * ( 1.0/2.0 - x3 )
    cdds1 = - 1.0/48.0 * t3
    
    cso0 = - 3.0/4.0 * w0
    cso1 = - 1.0/4.0 * w0
    rho = np.zeros((nbox+1,4))
    tau = np.zeros((nbox+1,4))
    jsc = np.zeros((nbox+1,4))
    for iq in range(2):

        rho[:,iq]=1e-25
        tau[:,iq]=1e-25
        jsc[:,iq]=1e-25
        for i in range(nmax):
            if(sortstates[iq,2,i]<1):continue
            if (sortenergies[iq,i] < - 1e-25):
                n = sortstates[iq,0,i]-1
                l = sortstates[iq,1,i]
                s = sortstates[iq,2,i]-1
                j = sortstates[iq,1,i] + spin(sortstates[iq,2,i])
                if (sortstates[iq,1,i] == 0): j = 0.5
                #print(iq,s,l,n)
                dwf = derivative_sca(wf[iq,s,l,n,1:],nbox,l)
                '''
                for ir in range(1,nbox):
                    tau[ir,iq] = tau[ir,iq] + (2*j+1)*((dwf[ir]\
                    -wf[iq,s,l,n,ir]/mesh[ir])**2+l*(l+1)*(wf[iq,s,l,n,ir]**2)\
                     /mesh[ir]**2)/(4*pi*mesh[ir]**2)

                    rho[ir,iq] = rho[ir,iq] + (2*j+1)*wf[iq,s,l,n,ir]\
                    *wf[iq,s,l,n,ir] / (4*pi*mesh[ir]**2)

                    jsc[ir,iq] = jsc[ir,iq] + (2*j+1)*(j*(j+1)-l*(l+1)-0.75)\
                    *wf[iq,s,l,n,ir]**2/(4*pi*mesh[ir]**3)
                '''

                tau[:,iq] = tau[:,iq] + (2*j+1)*((dwf[:]\
                -wf[iq,s,l,n,:]/mesh[:])**2+l*(l+1)*(wf[iq,s,l,n,:]**2)\
                /mesh[:]**2)/(4*pi*mesh[:]**2)

                rho[:,iq] = rho[:,iq] + (2*j+1)*wf[iq,s,l,n,:]\
                *wf[iq,s,l,n,:] / (4*pi*mesh[:]**2)

                jsc[:,iq] = jsc[:,iq] + (2*j+1)*(j*(j+1)-l*(l+1)-0.75)\
                *wf[iq,s,l,n,:]**2/(4*pi*mesh[:]**3)
                rho[0,iq] = rho[1,iq]
                tau[1,iq] = tau[2,iq]
                tau[0,iq] = tau[1,iq]


    rho[:,2]=rho[:,0] + rho[:,1]
    rho[0,2] = rho[1,2]
    rho[:,3]=rho[:,0] - rho[:,1]
    tau[:,2]=tau[:,0] + tau[:,1]
    tau[:,3]=tau[:,0] - tau[:,1]
    jsc[:,2]=jsc[:,0] + jsc[:,1]
    jsc[:,3]=jsc[:,0] - jsc[:,1]

    djsc = np.zeros(jsc.shape)
    drho = np.zeros(rho.shape)
    ddrho = np.zeros(rho.shape)
    laprho = np.zeros(rho.shape)

    for iq in range(2):
        for ir in range(nbox+1):
            if(ir < 1):
                djsc[ir,iq] = (-jsc[ir+2,iq] + 8*jsc[ir+1,iq] \
                 +8*jsc[ir+1,iq] - jsc[ir+2,iq])/(12*h)

                drho[ir,iq] = (-rho[ir+2,iq] + 8*rho[ir+1,iq] \
                 -8*rho[ir+1,iq] + rho[ir+2,iq])/(12*h)

                ddrho[ir,iq] = (-rho[ir+2,iq]+16*rho[ir+1,iq]-30*rho[ir,iq]\
                 +16*rho[ir+1,iq]-rho[ir+2,iq])/(12*h**2)
            elif (ir < 2):
                djsc[ir,iq] = (-jsc[ir+2,iq] + 8*jsc[ir+1,iq] \
                 +8*jsc[ir-1,iq] - jsc[ir,iq])/(12*h)

                drho[ir,iq] = (-rho[ir+2,iq] + 8*rho[ir+1,iq] \
                 -8*rho[ir-1,iq] + rho[ir,iq])/(12*h)

                ddrho[ir,iq] = (-rho[ir+2,iq]+16*rho[ir+1,iq]-30*rho[ir,iq]\
                 +16*rho[ir-1,iq]-rho[ir,iq])/(12*h**2)
            elif ((ir >= 2) and (ir <= nbox-2)):
                drho[ir,iq] = (-rho[ir+2,iq] + 8*rho[ir+1,iq] \
                 -8*rho[ir-1,iq] + rho[ir-2,iq])/(12*h)

                djsc[ir,iq] = (-jsc[ir+2,iq] + 8*jsc[ir+1,iq] \
                 -8*jsc[ir-1,iq] + jsc[ir-2,iq])/(12*h)

                ddrho[ir,iq] = (-rho[ir+2,iq]+16*rho[ir+1,iq]-30*rho[ir,iq]\
                 +16*rho[ir-1,iq]-rho[ir-2,iq])/(12*h**2)
            elif ((ir > nbox-2) and (ir!=nbox)):
                drho[ir,iq] = 0.
                ddrho[ir,iq] = 0.
                djsc[ir,iq] = 0.
            else:
                drho[ir,iq] = 0.
                ddrho[ir,iq] = 0.
                djsc[ir,iq] = 0.
        ddrho[0:3,iq]=ddrho[4,iq]

    drho[:,2] = drho[:,0] + drho[:,1]
    drho[:,3] = drho[:,0] - drho[:,1]
    djsc[:,2] = djsc[:,0] + djsc[:,1]
    djsc[:,3] = djsc[:,0] - djsc[:,1]
    ddrho[:,2] = ddrho[:,0] + ddrho[:,1]
    ddrho[:,3] = ddrho[:,0] - ddrho[:,1]
    for i in range(4):
        laprho[:,i] = ddrho[:,i] + 2./mesh[:]*drho[:,i]

    uc = np.zeros((nbox+1,2))
    ucso = np.zeros((nbox+1,2))
    umr = np.zeros((nbox+1,2))
    dumr = np.zeros((nbox+1,2))
    d2umr = np.zeros((nbox+1,2))
    udd = np.zeros((nbox+1,2))
    uso = np.zeros((nbox+1,2))
    ucoul = np.zeros((nbox+1))

    for iq in range(2):
        '''
        for ir in range(nbox+1):

            #Central Field U(r)
            uc[ir,iq] = 2*(a0r0-a1r1)*rho[ir,2] + 4*a1r1 * rho[ir,iq]  \
                           + (a0tau0-a1tau1) *tau[ir,2]+ 2 *a1tau1*tau[ir,iq] \
                           +2*( a0r0p-a1r1p )*laprho[ir,2] + 4 *a1r1p * laprho[ir,iq]
            #Part of U(r) coming from so)
            ucso[ir,iq] = (cso0-cso1 ) *(djsc[ir,2] + 2 * jsc[ir,2]/mesh[ir] ) \
                             + 2 *cso1 * ( djsc[ir,iq] + 2 * jsc[ir,iq] / mesh[ir] )
            #Mq(r) contributions
            umr[ir,iq] = hbar22m*cmcorr+(a0tau0-a1tau1)*rho[ir,2] + 2 * a1tau1*rho[ir,iq]
            dumr[ir,iq] = (a0tau0-a1tau1)*drho[ir,2] + 2 * a1tau1*drho[ir,iq]
            d2umr[ir,iq] = (a0tau0-a1tau1)*ddrho[ir,2] + 2 * a1tau1*ddrho[ir,iq]
            # t3 part of U(r)
            udd[ir,iq] = ( 2 + sig ) * (cddr0-cddr1)*rho[ir,2]**(sig+1)  \
                            +2*sig*cddr1*(rho[ir,0]**2+rho[ir,1]**2)*rho[ir,2]**(sig-1.) \
                            + 4 * cddr1 * rho[ir,iq] * rho[ir,2]**sig
            #spin-orbit part
            uso[ir,iq] = - (cso0-cso1 )*drho[ir,2]/mesh[ir] \
                             - 2 *cso1 * drho[ir,iq] / mesh[ir]
            if (True):
                uso[ir,iq] = uso[ir,iq]-(a0t0-a1t1) *jsc[ir,2] / mesh[ir] \
                             - 2 *a1t1 * jsc[ir,iq] / mesh[ir]
            #coulomb
            if (iq==1):
                tot1=0.0
                tot2=0.0
                for ir2 in range(0,ir):
                    tot1=tot1+rho[ir2,1]*(mesh[ir2]**2)

                for ir2 in range(ir,nbox+1):
                    tot2=tot2+rho[ir2,1]*mesh[ir2]
                ucoul[ir]=4.0*pi*e2*(tot1/mesh[ir]\
                + tot2)*h - e2*(3./pi)**(1./3.)*rho[ir,1]**(1./3.)
        '''
        #Central Field U(r)
        uc[:,iq] = 2*(a0r0-a1r1)*rho[:,2] + 4*a1r1 * rho[:,iq]  \
                       + (a0tau0-a1tau1) *tau[:,2]+ 2 *a1tau1*tau[:,iq] \
                       +2*( a0r0p-a1r1p )*laprho[:,2] + 4 *a1r1p * laprho[:,iq]
        #Part of U(r) coming from so)
        ucso[:,iq] = (cso0-cso1 ) *(djsc[:,2] + 2 * jsc[:,2]/mesh[:] ) \
                         + 2 *cso1 * ( djsc[:,iq] + 2 * jsc[:,iq] / mesh[:] )
        #Mq(r) contributions
        umr[:,iq] = hbar22m*cmcorr+(a0tau0-a1tau1)*rho[:,2] + 2 * a1tau1*rho[:,iq]
        dumr[:,iq] = (a0tau0-a1tau1)*drho[:,2] + 2 * a1tau1*drho[:,iq]
        d2umr[:,iq] = (a0tau0-a1tau1)*ddrho[:,2] + 2 * a1tau1*ddrho[:,iq]
        # t3 part of U(r)
        udd[:,iq] = ( 2 + sig ) * (cddr0-cddr1)*rho[:,2]**(sig+1)  \
                        +2*sig*cddr1*(rho[:,0]**2+rho[:,1]**2)*rho[:,2]**(sig-1.) \
                        + 4 * cddr1 * rho[:,iq] * rho[:,2]**sig
        #spin-orbit part
        uso[:,iq] = - (cso0-cso1 )*drho[:,2]/mesh[:] \
                         - 2 *cso1 * drho[:,iq] / mesh[:]
        if (True):
            uso[:,iq] = uso[:,iq]-(a0t0-a1t1) *jsc[:,2] / mesh[:] \
                         - 2 *a1t1 * jsc[:,iq] / mesh[:]
        #coulomb
        for ir in range(nbox+1):
            if (iq==1):
                tot1=0.0
                tot2=0.0
                for ir2 in range(0,ir):
                    tot1=tot1+rho[ir2,1]*(mesh[ir2]**2)
    
                for ir2 in range(ir,nbox+1):
                    tot2=tot2+rho[ir2,1]*mesh[ir2]
                ucoul[ir]=4.0*pi*e2*(tot1/mesh[ir]\
                + tot2)*h - e2*(3./pi)**(1./3.)*rho[ir,1]**(1./3.)
    hpsi = np.zeros(wf.shape)
    #dwf = np.zeros(rho[:,0].shape)
    ddwf = np.zeros(rho[:,0].shape)
    for iq in range(2):
        for i in range(nmax):
            if(sortstates[iq,2,i]<1):continue
            if (sortenergies[iq,i] < - 1e-25):
                n = sortstates[iq,0,i]-1
                l = sortstates[iq,1,i]
                s = sortstates[iq,2,i]-1
                j = sortstates[iq,1,i] + spin(sortstates[iq,2,i])
                if (sortstates[iq,1,i] == 0): j = 0.5
                dwf[1:] = derivative_sca(wf[iq,s,l,n,1:],nbox,l)
                ddwf[1:] = derivative_sca(dwf[1:],nbox,l)


                hpsi[iq,s,l,n,:] = umr[:,iq]*ddwf[:]+dumr[:,iq]*dwf[:] \
                    + (-uc[:,iq] -ucso[:,iq]-udd[:,iq] \
                    -uso[:,iq]*(j*(j+1.0)- l*(l+1.0) - 0.750)\
                    -dumr[:,iq]/mesh[:] - umr[:,iq]*l*(l+1.0)/mesh[:]**2) * wf[iq,s,l,n,:]
                if(iq==1): hpsi[iq,s,l,n,:] -= ucoul[:]*wf[iq,s,l,n,:]
        '''
        for s in range(2):
            for l in range(lmax):
                j = l + spin(s+1)
                if (l==0): j=0.5

                for n in range(0,2):
                    dwf[1:] = derivative_sca(wf[iq,s,l,n,1:],nbox,l)
                    ddwf[1:] = derivative_sca(dwf[1:],nbox,l)


                    hpsi[iq,s,l,n,:] = umr[:,iq]*ddwf[:]+dumr[:,iq]*dwf[:] \
                    + (-uc[:,iq] -ucso[:,iq]-udd[:,iq] \
                    -uso[:,iq]*(j*(j+1.0)- l*(l+1.0) - 0.750)\
                    -dumr[:,iq]/mesh[:] - umr[:,iq]*l*(l+1.0)/mesh[:]**2) * wf[iq,s,l,n,:]
                    if(iq==1): hpsi[iq,s,l,n,:] -= ucoul[:]*wf[iq,s,l,n,:]
        '''


    return hpsi

def derivative_sca(wf,nbox,l):
    dwf = np.zeros(wf.shape)
    boundary_condition = 2
    h_12 = h*12.00
    h_60 = h*60.00
    sig = ( l%2 - 0.50 ) * 2
    dwf[0] = ( 8.00 * wf[1] - wf[2] + sig * wf[0] ) / h_12
    dwf[1] = ( 45.00 * ( wf[2] - wf[0] ) - 9.00 * wf[3] \
         + wf[4] - sig * wf[0] ) / h_60
    dwf[2] = ( 45.00 * ( wf[3] - wf[1] ) - 9.00 * ( wf[4] - wf[0] ) \
         + wf[5] ) / h_60
    
    if ( boundary_condition == 0 or  \
        (boundary_condition == 2 and l%2 == 0) or \
        (boundary_condition == 3 and l != 2 * ( l // 2 )) ):
        dwf[nbox-1] = ( -8.00 * wf[nbox-2] + wf[nbox-1] + wf[nbox-3] ) / h_12
        dwf[nbox-2] = ( 45.00 * ( wf[nbox-1] - wf[nbox-3] ) + 9.00 * wf[nbox-4] \
            - wf[nbox-1] - wf[nbox-5] ) / h_60
        dwf[nbox-3] = ( 45.00 * ( wf[nbox-2] - wf[nbox-4] ) \
            - 9.00 * ( wf[nbox-1] - wf[nbox-5] ) - wf[nbox-6] ) / h_60
        
    if ( boundary_condition == 1 or  \
        (boundary_condition == 2 and l%2 != 0) or \
        (boundary_condition == 3 and l == 2 * ( l // 2 )) ):
        dwf[nbox-1] = ( - 54.0 * wf[nbox-2] + 45.0 * wf[nbox-1] + 10.0 * wf[nbox-3] - wf[nbox-4] ) / h_60
        dwf[nbox-2] = ( 36.0 * wf[nbox-1] + wf[nbox-2] - 45.0 * wf[nbox-3] \
            + 9.0 * wf[nbox-4] - wf[nbox-5] ) / h_60
        dwf[nbox-3] = ( 45.0 * ( wf[nbox-2] - wf[nbox-4] ) - 8.0 * wf[nbox-1]  \
            + 9.0 * wf[nbox-5] - wf[nbox-6] ) / h_60
    
    for i in range(3,nbox-4):
        dwf[i] = ( 45.00 * ( wf[i+1] - wf[i-1] )  \
            - 9.00 * ( wf[i+2] - wf[i-2] ) \
            + wf[i+3] - wf[i-3] ) / h_60
    return dwf

def NM_to_t(nm_params):
    c13=1.0/3.0
    c23=2.0/3.0
    #VMASS =   1.249838574232270 UNEDF1
    VMASS = 1.25000101440918243
    kfconst =(1.50*math.pi**2)**(1.0/3.0)    # (3Pi^2/2)^(1/3)
    CK      = 3.0/5.0*kfconst**2
    hbzero   =   20.735530000000000
    mpi=   138.03/197.3
    #E,K,SMASS,RHO,ASS,LASS, Crdr, CrdJ
    E = nm_params["E"]
    K = nm_params["K"]
    SMASS = nm_params["SMASS"]
    RHO = nm_params["RHO"]
    ASS = nm_params["ASS"]
    LASS = nm_params["LASS"]
    Crdr = nm_params["Crdr"]
    CrdJ = nm_params["CrdJ"]
    tauc=CK*RHO**c23
    u=(kfconst/mpi)*RHO**c13
    rho2=RHO**2
    Crho = [0.0,0.0]
    Cdrho = [0.0,0.0]
    Ctau = [0.0,0.0]
    # set/calculate sigma
    sigma=((1.0/3.0)*(-K+tauc*hbzero*(-3.0+4.0*SMASS)-9.0*E)) \
             /(tauc*hbzero*(-3.0+2.0*SMASS)+3.0*E)
    
    Crho[0]=(c13*(tauc*hbzero*(-3.0+(2.0-3.0*sigma)*SMASS) \
        +3.0*(1.0+sigma)*E))/(sigma*RHO)
    Cdrho[0]=(c13*RHO**(-1.0-sigma)*(tauc*hbzero*(3.0-2.0*SMASS)\
        -3.0*E))/sigma
    Ctau[0]=(hbzero*(SMASS-1.0))/RHO
    
    Crho[1]=(27.0*ASS*(1.0+sigma)-9.0*LASS \
        +5.0*tauc*hbzero*(5.0-6.0*VMASS+3.0*sigma*(-4.0+3.0*VMASS)) \
        +RHO*(40.0*tauc*Ctau[0]-60.0*tauc*sigma*Ctau[0]))/(27.0*sigma*RHO)
    Cdrho[1]=-(RHO**(-1.0-sigma)*(27.0*ASS-9.0*LASS \
        +5.0*tauc*hbzero*(5.0-6.0*VMASS) \
        +40.0*tauc*RHO*Ctau[0]))/(27.0*sigma)
    Ctau[1]=(hbzero-hbzero*VMASS+RHO*Ctau[0])/RHO
    
    t0  =  (8.0/3)*Crho[0]
    t1  =  4.0/3.0*(Ctau[0]-4.0*Crdr[0])
    t2  =  4.0/3.0*(3.0*Ctau[0]-6.0*Ctau[1]+4.0*Crdr[0]-8.0*Crdr[1])
    t3  =  16.0*Cdrho[0]
    x0  = -0.50*(3.0*Crho[1]/Crho[0]+1.0)
    x1  =  2.0*(-Ctau[0]-3.0*Ctau[1]+4.0*Crdr[0]+12.0*Crdr[1])/t1/3.0
    x2  = -2.0*(3.0*Ctau[0]-15.0*Ctau[1]+4.0*Crdr[0]-20.0*Crdr[1])/t2/3.0
    x3  = -0.50*(3.0*Cdrho[1]/Cdrho[0]+1.0)
    t4  =  (CrdJ[1]-CrdJ[0]) / 2.0
    t4p = -CrdJ[1]*4.0
    t_params = {"t0":t0,"x0":x0,"t1":t1,"x1":x1,"t2":t2,"x2":x2,"t3":t3,"x3":x3,"w0":t4p,"sig":1/sigma}
    #print(t_params)
    return t_params

# %% [markdown]
# The following cell defines a list of parameters (only one right now) and then loops over those parameters and runs the HF code to generate outputs and WFs.
#
# The inputs, outputs, and WFs are copied to a results folder (this can be changed) with some tag appended to the file name. In the future we may want to change how this tag is generated.

# %%
# params = [[-2483.45,13757.0],\
#           [-2503.45,13757.0],\
#           [-2353.45,14757.0],\
#           [-2583.45,12757.0],\
#           [-2383.45,13457.0],]

#default_params = {"t0":-2483.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13757.0,"x3":1.2630,"w0":125.0,"sig":6.0}
#nmdefault_params = {"E":-15.9843259547113412,"K":229.905998768288782,"SMASS":1.43365799002626937,"RHO":0.160573718963025164,"ASS":32.0099875506415614,"LASS":48.1461992412703239,"Crdr":[-76.793125,17.0058521875],"CrdJ":[-93.75,-31.25]}
nmdefault_params = {"E":-15.8,"K":220.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":40.004790480413600,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]}
nmparams = [\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":30.0,"Crdr":[-45.0,-90.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-60.0,-200.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":30.0,"Crdr":[-45.0,-90.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-45.0,-90.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":30.0,"Crdr":[-60.0,-90.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-45.0,-200.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":50.0,"Crdr":[-55.0,-190.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-45.0,-90.0],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        ]
nmparams = [\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":20.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":60.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":220.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":20.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        {"E":-15.8,"K":220.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":60.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        #{"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.165,"ASS":28.986789057772100,"LASS":30.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        #{"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.165,"ASS":28.0,"LASS":120.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        #{"E":-15.8,"K":240.0,"SMASS":0.992423332283364,"RHO":0.155,"ASS":28.0,"LASS":30.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        #{"E":-15.8,"K":200.0,"SMASS":0.992423332283364,"RHO":0.155,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]},\
        ]

errors = []
params = []
directory = '../HF'
for i in range(len(nmparams)):
    params.append(NM_to_t(nmparams[i]))
    make_input(params[i],0,directory)
    with cwd('../HF/'):
        errors.append(run_HF(str(i),0))

default_params = NM_to_t(nmdefault_params)
make_input(default_params,0,directory)
with cwd('../HF/'):
    errors.append(run_HF("default",0))

restartfile = '../HF/results/wf_numpy.bin.default'

h,nbox,lmax,nmax,sortstates,sortenergies,wf_default = read_wfs(restartfile)

# %% [markdown]
# Now we read the files back in and print the energies of the single particle states to see whats up.

# %%
'''
default_params = {"t0":-2483.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13757.0,"x3":1.2630,"w0":125.0,"sig":6.0}
restartfile = '../HF/results/wf_numpy.bin.default'

h,nbox,lmax,nmax,sortstates,sortenergies,wf_default = read_wfs(restartfile)
params = [\
          {"t0":-2483.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13757.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2383.45,"x0":0.77600,"t1":514.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13757.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2583.45,"x0":0.77600,"t1":454.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13757.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2383.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13957.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2583.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13557.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2383.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13557.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
          {"t0":-2583.45,"x0":0.77600,"t1":484.2300,"x1":-0.31700,"t2":-556.6900,"x2":-1.0,"t3":13557.0,"x3":1.2630,"w0":125.0,"sig":6.0},\
         ]
errors = [0,0,0,0,0,0,0]
'''
train_wfs = []
states = []
energies = []
defenergies=[]
levels = [0,0]
for i in range(len(params)):
    if(errors[i] == 1): continue
    restartfile = '../HF/results/wf_numpy.bin.'+str(i)
    h,nbox,lmax,nmax,sortstates_t,sortenergies,wf = read_wfs(restartfile)
    train_wfs.append(wf)
    states.append(sortstates)
    directory='../HF'
    hpsi = get_hpsi(params[i],h,nbox,lmax,nmax,sortstates,sortenergies,wf,directory)
    dhpsi = get_hpsi(default_params,h,nbox,lmax,nmax,sortstates,sortenergies,wf_default,directory)

    #Calculate energies as a test for levels
    energy = [[],[]]
    for isospin in range(2):
        occupied = 0
        for i in range(lmax):
            level = i
            i_s = sortstates[isospin,2,level]-1
            i_l = sortstates[isospin,1,level]
            i_n = sortstates[isospin,0,level]-1
            if(i_s < 0): continue
            occupied += 1
            sp_en = np.sum(-h*wf[isospin,i_s,i_l,i_n,:]*hpsi[isospin,i_s,i_l,i_n,:])
            defsp_en = np.sum(-h*wf_default[isospin,i_s,i_l,i_n,:]*dhpsi[isospin,i_s,i_l,i_n,:])
            energy[isospin].append(sp_en)
            defenergies.append(defsp_en)
            #print("Level: {}, N: {}, L: {}, S: {}".format(level+1,i_n+1,i_l,i_s))
            #print("Energy: {}".format(energy[isospin][i]))
        levels[isospin] = occupied
    energies.append(energy)
defenergies = defenergies[:levels[0]+levels[1]]
#h,nbox,lmax,nmax,sortstates,sortenergies,wf = read_wfs()
# npart = 0
# for i in range(nmax):
#     if(sortstates[0,0,i]>0):
#         nfill = int(2*(sortstates[0,1,i]+spin(sortstates[0,2,i])) + 1)
#         if (sortstates[0,1,i] == 0): nfill = 2
#         npart += nfill
#         print(npart)

# %% [markdown]
# Now we can calculate the hpsi (or, G) objects from Wfs. Here I am reading in training Wfs just as a test.

# %%
for i in range(len(params)):
    if(errors[i] == 1): continue
    # The following is to simply read in the trial WFs during testing
    restartfile = '../HF/results/wf_numpy.bin.'+str(i)
    h,nbox,lmax,nmax,sortstates,sortenergies,wf = read_wfs(restartfile)

    # get hpsi
    hpsi = get_hpsi(params[i],h,nbox,lmax,nmax,sortstates,sortenergies,wf)

    #Calculate energies as a test for levels
    occupied = 0
    for i in range(nmax):
        isospin = 0
        level = i
        i_s = sortstates[isospin,2,level]-1
        i_l = sortstates[isospin,1,level]
        i_n = sortstates[isospin,0,level]-1
        if(i_s < 0): continue
        occupied += 1
        #print("Level: {}, N: {}, L: {}, S: {}".format(level+1,i_n+1,i_l,i_s))
        #print("Energy: {}".format(np.sum(-h*wf[isospin,i_s,i_l,i_n,:]*hpsi[isospin,i_s,i_l,i_n,:])))

#print("There are {} occupied levels!".format(occupied))

# %%
global count
count = 0

start_time = time.time()
global prev_time 
prev_time = time.time()

train_num = len(train_wfs)

print("Training with {} WFs, each one with {} total states".format(train_num,sum(levels)))

ak = np.zeros((train_num,sum(levels)))
lam = np.zeros((sum(levels)))
coeffs = np.zeros((train_num*sum(levels) + sum(levels)))
coeffs[0:train_num*sum(levels)] = 0.0
coeffs[train_num*sum(levels):] = 25.0
coeffs[0:sum(levels)] = 1.0
tag = "test"
directory = '/mnt/ram/HF.'+tag
os.system("mkdir -p {directory}".format(directory=directory))
os.chdir("/home/kyle/code/GalerkinEC/EC")

os.system("cp ../HF/main {directory}/.".format(directory=directory))
#coeffs = sol.x
nmtest_params = {"E":-15.9843259547113412,"K":215.905998768288782,"SMASS":1.43365799002626937,"RHO":0.160573718963025164,"ASS":32.0099875506415614,"LASS":57.1461992412703239,"Crdr":[-76.793125,17.0058521875],"CrdJ":[-93.75,-31.25]}
nmtest_params={"E":-15.8,"K":220.0,"SMASS":0.992423332283364,"RHO":0.158706769332587,"ASS":28.986789057772100,"LASS":120.0,"Crdr":[-45.1351310222373,-145.382167908057],"CrdJ":[-74.0263331764599,-35.6582611147917]}

test_params = NM_to_t(nmtest_params)
#print(nm_sampleparams[0])
#galerkin(coeffs,wfs,states,levels,test_params)

#min_dict = {'col_deriv': 0, 'xtol': 1.49012e-30,'maxfev': 5000, 'band': None, 'eps': None, 'factor': 100, 'diag': None}
hybr_dict = {'col_deriv': 0, 'xtol': 1.49012e-6,'maxfev': 5000, 'band': None, 'eps': None, 'factor': 100, 'diag': None}
#sol = optimize.root(galerkin, coeffs, args=(train_wfs,states,levels,test_params), method='df-sane',options={"maxfev":1000,"disp":True})#, options=hybr_dict)
#sol = optimize.root(galerkin, coeffs, args=(train_wfs,sortstates,levels,test_params), method='krylov',options={"maxiter":300,"disp":True})#, options=hybr_dict)
#sol = optimize.root(galerkin, coeffs, args=(train_wfs,states,levels,test_params), method='lm',options={"maxiter":400})#, options=hybr_dict)
sol = optimize.root(galerkin, coeffs, args=(train_wfs,sortstates,levels,test_params,directory), method='hybr', options=hybr_dict)
def funcPerf(Xi):
    global train_wfs
    global sortstates
    global levels
    global test_params
    global directory
    print(galerkin(Xi,train_wfs,sortstates,levels,test_params,directory))
    return
#min_dict = {'xtol': 0.0001, 'ftol': 0.0001, 'maxiter': None, 'maxfev': 5000, 'disp': True, 'direc': None, 'return_all': False}
#min_dict = {'gtol': 1e-05, 'eps': 1.4901161193847656e-08, 'maxiter': None, 'disp': True, 'return_all': False, 'finite_diff_rel_step': None}
#sol = optimize.minimize(galerkin_min, coeffs, args=(train_wfs,sortstates,levels,test_params,directory), method='Powell', options=min_dict,callback=funcPerf)
print(sol.x)
print(galerkin(sol.x,train_wfs,sortstates,levels,test_params,directory))
print("Total time took: {}".format(time.time()-start_time))
# Out:
# Training with 4 WFs, each one with 13 total states
# Iteration 1
# Iteration time: 0.005623340606689453
# Iteration 2
# Iteration time: 0.1979074478149414
# Iteration 3
# Iteration time: 0.1826155185699463
# Iteration 4
# Iteration time: 0.17645525932312012
# Iteration 5
# Iteration time: 0.16909337043762207
# Iteration 6
# Iteration time: 0.20694184303283691
# Iteration 7
# Iteration time: 0.1989428997039795
# Iteration 8
# Iteration time: 0.17894268035888672
# Iteration 9
# Iteration time: 0.18094110488891602
# Iteration 10
# Iteration time: 0.19965767860412598
# Iteration 11
# Iteration time: 0.18589472770690918
# Iteration 12
# Iteration time: 0.181380033493042
# Iteration 13
# Iteration time: 0.16590261459350586
# Iteration 14
# Iteration time: 0.17599129676818848
# Iteration 15
# Iteration time: 0.16959834098815918
# Iteration 16
# Iteration time: 0.18292999267578125
# Iteration 17
# Iteration time: 0.17677807807922363
# Iteration 18
# Iteration time: 0.1867818832397461
# Iteration 19
# Iteration time: 0.17200493812561035
# Iteration 20
# Iteration time: 0.1894059181213379
# Iteration 21
# Iteration time: 0.17359519004821777
# Iteration 22
# Iteration time: 0.16881918907165527
# Iteration 23
# Iteration time: 0.1796417236328125
# Iteration 24
# Iteration time: 0.19006896018981934
# Iteration 25
# Iteration time: 0.1739034652709961
# Iteration 26
# Iteration time: 0.1890103816986084
# Iteration 27
# Iteration time: 0.19726276397705078
# Iteration 28
# Iteration time: 0.18166589736938477
# Iteration 29
# Iteration time: 0.17864060401916504
# Iteration 30
# Iteration time: 0.17180466651916504
# Iteration 31
# Iteration time: 0.1950540542602539
# Iteration 32
# Iteration time: 0.16913843154907227
# Iteration 33
# Iteration time: 0.17959380149841309
# Iteration 34
# Iteration time: 0.19903135299682617
# Iteration 35
# Iteration time: 0.1826016902923584
# Iteration 36
# Iteration time: 0.1782524585723877
# Iteration 37
# Iteration time: 0.1855926513671875
# Iteration 38
# Iteration time: 0.18164420127868652
# Iteration 39
# Iteration time: 0.18942546844482422
# Iteration 40
# Iteration time: 0.1875896453857422
# Iteration 41
# Iteration time: 0.1739366054534912
# Iteration 42
# Iteration time: 0.17509675025939941
# Iteration 43
# Iteration time: 0.18876314163208008
# Iteration 44
# Iteration time: 0.18108582496643066
# Iteration 45
# Iteration time: 0.1775052547454834
# Iteration 46
# Iteration time: 0.1958770751953125
# Iteration 47
# Iteration time: 0.1995837688446045
# Iteration 48
# Iteration time: 0.1769425868988037
# Iteration 49
# Iteration time: 0.20385217666625977
# Iteration 50
# Iteration time: 0.1838693618774414
# Iteration 51
# Iteration time: 0.19021320343017578
# Iteration 52
# Iteration time: 0.18331599235534668
# Iteration 53
# Iteration time: 0.19526314735412598
# Iteration 54
# Iteration time: 0.19016098976135254
# Iteration 55
# Iteration time: 0.1787736415863037
# Iteration 56
# Iteration time: 0.17504096031188965
# Iteration 57
# Iteration time: 0.17355561256408691
# Iteration 58
# Iteration time: 0.18938398361206055
# Iteration 59
# Iteration time: 0.19758820533752441
# Iteration 60
# Iteration time: 0.20450568199157715
# Iteration 61
# Iteration time: 0.17866802215576172
# Iteration 62
# Iteration time: 0.18033337593078613
# Iteration 63
# Iteration time: 0.1783747673034668
# Iteration 64
# Iteration time: 0.18378353118896484
# Iteration 65
# Iteration time: 0.17988181114196777
# Iteration 66
# Iteration time: 0.18065524101257324
# Iteration 67
# Iteration time: 0.1822664737701416
# Iteration 68
# Iteration time: 0.19618463516235352
# Iteration 69
# Iteration time: 0.18445348739624023
# Iteration 70
# Iteration time: 0.19930243492126465
# Iteration 71
# Iteration time: 0.1879560947418213
# Iteration 72
# Iteration time: 0.17348575592041016
# Iteration 73
# Iteration time: 0.17447757720947266
# Iteration 74
# Iteration time: 0.18000030517578125
# Iteration 75
# Iteration time: 0.19112014770507812
# Iteration 76
# Iteration time: 0.18218278884887695
# Iteration 77
# Iteration time: 0.1876213550567627
# Iteration 78
# Iteration time: 0.18059134483337402
# Iteration 79
# Iteration time: 0.17322468757629395
# Iteration 80
# Iteration time: 0.18017578125
# Iteration 81
# Iteration time: 0.17867279052734375
# Iteration 82
# Iteration time: 0.18561100959777832
# Iteration 83
# Iteration time: 0.1884915828704834
# Iteration 84
# Iteration time: 0.17240643501281738
# Iteration 85
# Iteration time: 0.17624258995056152
# Iteration 86
# Iteration time: 0.18137788772583008
# Iteration 87
# Iteration time: 0.18793368339538574
# Iteration 88
# Iteration time: 0.1788642406463623
# Iteration 89
# Iteration time: 0.18204951286315918
# Iteration 90
# Iteration time: 0.17845702171325684
# Iteration 91
# Iteration time: 0.1711289882659912
# Iteration 92
# Iteration time: 0.18140077590942383
# Iteration 93
# Iteration time: 0.1949329376220703
# Iteration 94
# Iteration time: 0.17564606666564941
# Iteration 95
# Iteration time: 0.18090510368347168
# Iteration 96
# Iteration time: 0.1810457706451416
# Iteration 97
# Iteration time: 0.18466925621032715
# Iteration 98
# Iteration time: 0.17807817459106445
# Iteration 99
# Iteration time: 0.1749098300933838
# Iteration 100
# Iteration time: 0.1767714023590088
# [ 3.99730592e-03  2.35208758e-03  1.94340946e-03  1.00446632e-03
#  -4.75287679e-04  1.26322843e-03  5.99602084e-04 -5.13450440e-03
#  -3.20910167e-04 -6.34396039e-04 -5.35326476e-04 -7.02177458e-04
#  -2.25805222e-03  4.17005008e-03  2.35936791e-03  1.94065847e-03
#   9.94567612e-04 -7.56785062e-04  1.25434246e-03  5.96044970e-04
#  -5.29181899e-03 -3.19798008e-04 -6.28706827e-04 -5.33313276e-04
#  -6.93955108e-04 -2.19822025e-03  3.99206695e-03  2.35511102e-03
#   1.95463349e-03  1.00716813e-03 -4.48950278e-04  1.27102343e-03
#   6.09954372e-04 -5.10870299e-03 -3.18563849e-04 -6.34903286e-04
#  -5.27481977e-04 -6.96938469e-04 -2.29457123e-03  4.15478366e-03
#   2.36114599e-03  1.94045106e-03  9.99921243e-04 -7.17527447e-04
#   1.25982800e-03  6.10648952e-04 -5.25956700e-03 -3.16801024e-04
#  -6.30065252e-04 -5.29475291e-04 -6.89164517e-04 -2.23780715e-03
#  -4.93246632e-05 -1.85430133e-05 -3.60556334e-06  1.15631200e-06
#   1.32988681e-05 -1.90264039e-06  2.24763569e-06  6.87862499e-05
#  -5.45529134e-06 -2.86964149e-06  1.43326691e-06  5.98563482e-06
#   3.28117826e-05]
# Iteration 101
# Iteration time: 0.17090821266174316
# Iteration 102
# Iteration time: 0.18228363990783691
# Iteration 103
# Iteration time: 0.17105460166931152
# Iteration 104
# Iteration time: 0.17701077461242676
# Iteration 105
# Iteration time: 0.1831061840057373
# Iteration 106
# Iteration time: 0.16515874862670898
# Iteration 107
# Iteration time: 0.1621253490447998
# Iteration 108
# Iteration time: 0.16176819801330566
# Iteration 109
# Iteration time: 0.15732550621032715
# Iteration 110
# Iteration time: 0.16846442222595215
# Iteration 111
# Iteration time: 0.15730786323547363
# Iteration 112
# Iteration time: 0.14703822135925293
# Iteration 113
# Iteration time: 0.14639544486999512
# Iteration 114
# Iteration time: 0.14919686317443848
# Iteration 115
# Iteration time: 0.1579883098602295
# Iteration 116
# Iteration time: 0.1533522605895996
# Iteration 117
# Iteration time: 0.14792704582214355
# Iteration 118
# Iteration time: 0.14998579025268555
# Iteration 119
# Iteration time: 0.14732646942138672
# Iteration 120
# Iteration time: 0.15424132347106934
# Iteration 121
# Iteration time: 0.14939045906066895
# Iteration 122
# Iteration time: 0.14934730529785156
# Iteration 123
# Iteration time: 0.14194607734680176
# Iteration 124
# Iteration time: 0.1520404815673828
# Iteration 125
# Iteration time: 0.1470475196838379
# Iteration 126
# Iteration time: 0.1507701873779297
# Iteration 127
# Iteration time: 0.14650821685791016
# Iteration 128
# Iteration time: 0.14946532249450684
# Iteration 129
# Iteration time: 0.14422369003295898
# Iteration 130
# Iteration time: 0.15022897720336914
# Iteration 131
# Iteration time: 0.15021491050720215
# Iteration 132
# Iteration time: 0.1531810760498047
# Iteration 133
# Iteration time: 0.1497340202331543
# Iteration 134
# Iteration time: 0.14921140670776367
# Iteration 135
# Iteration time: 0.14731073379516602
# Iteration 136
# Iteration time: 0.14404559135437012
# Iteration 137
# Iteration time: 0.1431419849395752
# Iteration 138
# Iteration time: 0.144578218460083
# Iteration 139
# Iteration time: 0.14905786514282227
# Iteration 140
# Iteration time: 0.14745354652404785
# Iteration 141
# Iteration time: 0.1432960033416748
# Iteration 142
# Iteration time: 0.14705920219421387
# Iteration 143
# Iteration time: 0.14168858528137207
# Iteration 144
# Iteration time: 0.1520061492919922
# Iteration 145
# Iteration time: 0.14296841621398926
# Iteration 146
# Iteration time: 0.14919161796569824
# Iteration 147
# Iteration time: 0.14186501502990723
# Iteration 148
# Iteration time: 0.1500859260559082
# Iteration 149
# Iteration time: 0.15006327629089355
# Iteration 150
# Iteration time: 0.15590858459472656
# Iteration 151
# Iteration time: 0.14561772346496582
# Iteration 152
# Iteration time: 0.15426182746887207
# Iteration 153
# Iteration time: 0.15609979629516602
# Iteration 154
# Iteration time: 0.14739418029785156
# Iteration 155
# Iteration time: 0.14403343200683594
# Iteration 156
# Iteration time: 0.15813589096069336
# Iteration 157
# Iteration time: 0.1437995433807373
# Iteration 158
# Iteration time: 0.1501781940460205
# Iteration 159
# Iteration time: 0.13981342315673828
# Iteration 160
# Iteration time: 0.1552104949951172
# Iteration 161
# Iteration time: 0.1544637680053711
# Iteration 162
# Iteration time: 0.1516110897064209
# Iteration 163
# Iteration time: 0.14738011360168457
# Iteration 164
# Iteration time: 0.14805197715759277
# Iteration 165
# Iteration time: 0.1435229778289795
# Iteration 166
# Iteration time: 0.1497499942779541
# Iteration 167
# Iteration time: 0.14564847946166992
# Iteration 168
# Iteration time: 0.14997148513793945
# Iteration 169
# Iteration time: 0.14315128326416016
# Iteration 170
# Iteration time: 0.14611220359802246
# Iteration 171
# Iteration time: 0.14356637001037598
# Iteration 172
# Iteration time: 0.14219141006469727
# Iteration 173
# Iteration time: 0.14013981819152832
# Iteration 174
# Iteration time: 0.14931988716125488
# Iteration 175
# Iteration time: 0.14417767524719238
# Iteration 176
# Iteration time: 0.15115761756896973
# Iteration 177
# Iteration time: 0.14480304718017578
# Iteration 178
# Iteration time: 0.15921473503112793
# Iteration 179
# Iteration time: 0.16609716415405273
# Iteration 180
# Iteration time: 0.16001558303833008
# Iteration 181
# Iteration time: 0.17085051536560059
# Iteration 182
# Iteration time: 0.1566770076751709
# Iteration 183
# Iteration time: 0.17713475227355957
# Iteration 184
# Iteration time: 0.15855646133422852
# Iteration 185
# Iteration time: 0.1483457088470459
# Iteration 186
# Iteration time: 0.14667129516601562
# Iteration 187
# Iteration time: 0.15061616897583008
# Iteration 188
# Iteration time: 0.14663410186767578
# Iteration 189
# Iteration time: 0.1482081413269043
# Iteration 190
# Iteration time: 0.15532469749450684
# Iteration 191
# Iteration time: 0.1495223045349121
# Iteration 192
# Iteration time: 0.1519484519958496
# Iteration 193
# Iteration time: 0.15963411331176758
# Iteration 194
# Iteration time: 0.14996838569641113
# Iteration 195
# Iteration time: 0.15418410301208496
# Iteration 196
# Iteration time: 0.15349745750427246
# Iteration 197
# Iteration time: 0.14043498039245605
# Iteration 198
# Iteration time: 0.15405511856079102
# Iteration 199
# Iteration time: 0.1438131332397461
# Iteration 200
# Iteration time: 0.15152525901794434
# [-4.39140636e-05 -2.76868343e-06 -7.15279598e-06  2.53893574e-05
#  -4.02505374e-06  1.74904391e-05  3.81446461e-05  4.89640146e-05
#  -1.48844391e-05 -2.08511679e-05 -5.32122797e-05 -6.37711814e-05
#   1.89855014e-05 -4.36834674e-05 -2.62310059e-06 -6.87634929e-06
#   2.54895423e-05 -3.92873334e-06  1.77303851e-05  3.81249350e-05
#   4.90871773e-05 -1.47282203e-05 -2.05715589e-05 -5.29944550e-05
#  -6.34511755e-05  1.89767985e-05 -4.41089648e-05 -2.84378178e-06
#  -7.35958366e-06  2.52749890e-05 -4.03522996e-06  1.72340135e-05
#   3.81952173e-05  4.84890359e-05 -1.47811107e-05 -2.09249985e-05
#  -5.28068054e-05 -6.39515881e-05  1.91934052e-05 -4.36008303e-05
#  -2.52037861e-06 -7.15334661e-06  2.55345053e-05 -4.02219971e-06
#   1.75348628e-05  3.82404624e-05  4.91023186e-05 -1.45534488e-05
#  -2.05464865e-05 -5.28244939e-05 -6.35827476e-05  1.91241157e-05
#  -4.02478828e-10  1.03204070e-08  4.18497468e-08  1.08082587e-09
#   1.27899535e-06  6.16065814e-08  2.16304308e-09 -6.61289989e-09
#  -3.64472308e-09  2.13426143e-09 -3.67599651e-09  6.86898760e-10
#   4.84514804e-08]
# Iteration 201
# Iteration time: 0.150787353515625
# Iteration 202
# Iteration time: 0.14979791641235352
# Iteration 203
# Iteration time: 0.17579936981201172
# Iteration 204
# Iteration time: 0.18392491340637207
# Iteration 205
# Iteration time: 0.15410518646240234
# Iteration 206
# Iteration time: 0.1599102020263672
# Iteration 207
# Iteration time: 0.15101861953735352
# Iteration 208
# Iteration time: 0.15376877784729004
# Iteration 209
# Iteration time: 0.14903020858764648
# Iteration 210
# Iteration time: 0.14854955673217773
# Iteration 211
# Iteration time: 0.1436173915863037
# Iteration 212
# Iteration time: 0.14771437644958496
# Iteration 213
# Iteration time: 0.14757275581359863
# Iteration 214
# Iteration time: 0.15617871284484863
# Iteration 215
# Iteration time: 0.15872478485107422
# Iteration 216
# Iteration time: 0.15327072143554688
# Iteration 217
# Iteration time: 0.1482527256011963
# Iteration 218
# Iteration time: 0.15717840194702148
# Iteration 219
# Iteration time: 0.16991686820983887
# Iteration 220
# Iteration time: 0.16735625267028809
# Iteration 221
# Iteration time: 0.1725473403930664
# Iteration 222
# Iteration time: 0.1656937599182129
# Iteration 223
# Iteration time: 0.15437722206115723
# Iteration 224
# Iteration time: 0.15095305442810059
# Iteration 225
# Iteration time: 0.14541101455688477
# Iteration 226
# Iteration time: 0.15138769149780273
# Iteration 227
# Iteration time: 0.14859437942504883
# Iteration 228
# Iteration time: 0.15422368049621582
# Iteration 229
# Iteration time: 0.14312338829040527
# Iteration 230
# Iteration time: 0.15106987953186035
# Iteration 231
# Iteration time: 0.15797162055969238
# Iteration 232
# Iteration time: 0.14878535270690918
# Iteration 233
# Iteration time: 0.14623260498046875
# Iteration 234
# Iteration time: 0.15043997764587402
# Iteration 235
# Iteration time: 0.1504654884338379
# Iteration 236
# Iteration time: 0.16074514389038086
# Iteration 237
# Iteration time: 0.14203453063964844
# Iteration 238
# Iteration time: 0.15020751953125
# Iteration 239
# Iteration time: 0.14897871017456055
# Iteration 240
# Iteration time: 0.15854191780090332
# Iteration 241
# Iteration time: 0.14404511451721191
# Iteration 242
# Iteration time: 0.17265081405639648
# Iteration 243
# Iteration time: 0.16773486137390137
# Iteration 244
# Iteration time: 0.16005778312683105
# Iteration 245
# Iteration time: 0.14392518997192383
# Iteration 246
# Iteration time: 0.15045380592346191
# Iteration 247
# Iteration time: 0.15760588645935059
# Iteration 248
# Iteration time: 0.14944148063659668
# Iteration 249
# Iteration time: 0.15903067588806152
# Iteration 250
# Iteration time: 0.16239190101623535
# Iteration 251
# Iteration time: 0.14834880828857422
# Iteration 252
# Iteration time: 0.15690350532531738
# Iteration 253
# Iteration time: 0.14911818504333496
# Iteration 254
# Iteration time: 0.15245461463928223
# Iteration 255
# Iteration time: 0.1465895175933838
# Iteration 256
# Iteration time: 0.14919233322143555
# Iteration 257
# Iteration time: 0.14638519287109375
# Iteration 258
# Iteration time: 0.16203594207763672
# Iteration 259
# Iteration time: 0.15325140953063965
# Iteration 260
# Iteration time: 0.15642690658569336
# Iteration 261
# Iteration time: 0.15300464630126953
# Iteration 262
# Iteration time: 0.1502234935760498
# Iteration 263
# Iteration time: 0.14668536186218262
# Iteration 264
# Iteration time: 0.14955854415893555
# Iteration 265
# Iteration time: 0.14022374153137207
# Iteration 266
# Iteration time: 0.16267633438110352
# Iteration 267
# Iteration time: 0.14157342910766602
# Iteration 268
# Iteration time: 0.14937543869018555
# Iteration 269
# Iteration time: 0.14873266220092773
# Iteration 270
# Iteration time: 0.15400910377502441
# Iteration 271
# Iteration time: 0.14951443672180176
# Iteration 272
# Iteration time: 0.15438246726989746
# Iteration 273
# Iteration time: 0.14572429656982422
# Iteration 274
# Iteration time: 0.1554555892944336
# Iteration 275
# Iteration time: 0.14615607261657715
# Iteration 276
# Iteration time: 0.1624438762664795
# Iteration 277
# Iteration time: 0.15337133407592773
# Iteration 278
# Iteration time: 0.1510639190673828
# Iteration 279
# Iteration time: 0.14279603958129883
# Iteration 280
# Iteration time: 0.15484356880187988
# Iteration 281
# Iteration time: 0.14205694198608398
# Iteration 282
# Iteration time: 0.1592557430267334
# Iteration 283
# Iteration time: 0.14879274368286133
# Iteration 284
# Iteration time: 0.14771294593811035
# Iteration 285
# Iteration time: 0.1468815803527832
# Iteration 286
# Iteration time: 0.1482386589050293
# Iteration 287
# Iteration time: 0.13825654983520508
# Iteration 288
# Iteration time: 0.15289616584777832
# Iteration 289
# Iteration time: 0.1420271396636963
# Iteration 290
# Iteration time: 0.15128612518310547
# Iteration 291
# Iteration time: 0.14502763748168945
# Iteration 292
# Iteration time: 0.14661383628845215
# Iteration 293
# Iteration time: 0.1463334560394287
# Iteration 294
# Iteration time: 0.14817595481872559
# Iteration 295
# Iteration time: 0.14519071578979492
# Iteration 296
# Iteration time: 0.1494603157043457
# Iteration 297
# Iteration time: 0.14090752601623535
# Iteration 298
# Iteration time: 0.14580035209655762
# Iteration 299
# Iteration time: 0.14553380012512207
# Iteration 300
# Iteration time: 0.16170644760131836
# [ 8.68330546e-06 -4.89348846e-06  8.15510610e-07 -7.13433935e-06
#   1.06490214e-05 -4.22812608e-07  1.76317441e-07 -6.83677129e-06
#  -1.47825638e-05 -2.30553925e-05 -2.02744105e-05 -3.39089743e-05
#  -1.25405463e-05  8.51084253e-06 -5.02971601e-06  7.57744850e-07
#  -6.97943048e-06  1.10366305e-05 -2.55477921e-07  3.97941109e-07
#  -7.03172884e-06 -1.46177653e-05 -2.29222324e-05 -2.00703534e-05
#  -3.37447431e-05 -1.24583452e-05  8.49747060e-06 -4.97095945e-06
#   7.05225322e-07 -7.37329094e-06  1.06218465e-05 -6.23819371e-07
#  -1.09348878e-07 -7.17990908e-06 -1.46897668e-05 -2.31120910e-05
#  -1.98830095e-05 -3.40420278e-05 -1.24179659e-05  8.60571391e-06
#  -4.95229681e-06  6.00689237e-07 -7.09534310e-06  1.08770486e-05
#  -4.62704616e-07  1.44648974e-07 -6.86893094e-06 -1.44991817e-05
#  -2.28680387e-05 -1.98899026e-05 -3.37728924e-05 -1.24113425e-05
#  -2.14987837e-06 -1.16971505e-06 -1.67622975e-06  5.07412008e-07
#   8.21325903e-07  5.98908307e-08  1.31714248e-06  2.42385552e-06
#   9.48472532e-07  3.50917168e-07 -4.74650268e-07 -6.79176009e-07
#   9.32390909e-07]
# Iteration 301
# Iteration time: 0.15080547332763672
# Iteration 302
# Iteration time: 0.15690040588378906
# Iteration 303
# Iteration time: 0.14410018920898438
# Iteration 304
# Iteration time: 0.15641474723815918
# Iteration 305
# Iteration time: 0.14362764358520508
# Iteration 306
# Iteration time: 0.14602971076965332
# Iteration 307
# Iteration time: 0.14535260200500488
# Iteration 308
# Iteration time: 0.14870953559875488
# Iteration 309
# Iteration time: 0.14403605461120605
# Iteration 310
# Iteration time: 0.15459489822387695
# Iteration 311
# Iteration time: 0.14805364608764648
# Iteration 312
# Iteration time: 0.15604186058044434
# Iteration 313
# Iteration time: 0.14197444915771484
# Iteration 314
# Iteration time: 0.16120576858520508
# Iteration 315
# Iteration time: 0.1501927375793457
# Iteration 316
# Iteration time: 0.15529441833496094
# Iteration 317
# Iteration time: 0.15003085136413574
# Iteration 318
# Iteration time: 0.17317533493041992
# Iteration 319
# Iteration time: 0.16834211349487305
# Iteration 320
# Iteration time: 0.17335867881774902
# Iteration 321
# Iteration time: 0.1541426181793213
# Iteration 322
# Iteration time: 0.16866731643676758
# Iteration 323
# Iteration time: 0.1642615795135498
# Iteration 324
# Iteration time: 0.16417574882507324
# Iteration 325
# Iteration time: 0.1430206298828125
# Iteration 326
# Iteration time: 0.15818428993225098
# Iteration 327
# Iteration time: 0.14782953262329102
# Iteration 328
# Iteration time: 0.1713876724243164
# Iteration 329
# Iteration time: 0.15839076042175293
# Iteration 330
# Iteration time: 0.14823365211486816
# Iteration 331
# Iteration time: 0.14312195777893066
# Iteration 332
# Iteration time: 0.14737534523010254
# Iteration 333
# Iteration time: 0.16229915618896484
# Iteration 334
# Iteration time: 0.1567850112915039
# Iteration 335
# Iteration time: 0.14528369903564453
# Iteration 336
# Iteration time: 0.1671276092529297
# Iteration 337
# Iteration time: 0.1502211093902588
# Iteration 338
# Iteration time: 0.1497197151184082
# Iteration 339
# Iteration time: 0.14524292945861816
# Iteration 340
# Iteration time: 0.14928269386291504
# Iteration 341
# Iteration time: 0.1489107608795166
# Iteration 342
# Iteration time: 0.1685314178466797
# Iteration 343
# Iteration time: 0.17385005950927734
# Iteration 344
# Iteration time: 0.18464040756225586
# Iteration 345
# Iteration time: 0.16631269454956055
# Iteration 346
# Iteration time: 0.1594390869140625
# Iteration 347
# Iteration time: 0.14952373504638672
# Iteration 348
# Iteration time: 0.1573631763458252
# Iteration 349
# Iteration time: 0.1584150791168213
# Iteration 350
# Iteration time: 0.14783406257629395
# Iteration 351
# Iteration time: 0.144087553024292
# Iteration 352
# Iteration time: 0.14773082733154297
# Iteration 353
# Iteration time: 0.14716672897338867
# Iteration 354
# Iteration time: 0.1545112133026123
# Iteration 355
# Iteration time: 0.1400768756866455
# Iteration 356
# Iteration time: 0.1507740020751953
# Iteration 357
# Iteration time: 0.15001440048217773
# Iteration 358
# Iteration time: 0.15746283531188965
# Iteration 359
# Iteration time: 0.14934134483337402
# Iteration 360
# Iteration time: 0.1513962745666504
# Iteration 361
# Iteration time: 0.14416265487670898
# Iteration 362
# Iteration time: 0.1576378345489502
# Iteration 363
# Iteration time: 0.164414644241333
# Iteration 364
# Iteration time: 0.15453886985778809
# Iteration 365
# Iteration time: 0.1478409767150879
# Iteration 366
# Iteration time: 0.1555328369140625
# Iteration 367
# Iteration time: 0.1448535919189453
# Iteration 368
# Iteration time: 0.1727161407470703
# Iteration 369
# Iteration time: 0.15908265113830566
# Iteration 370
# Iteration time: 0.16397953033447266
# Iteration 371
# Iteration time: 0.14507651329040527
# Iteration 372
# Iteration time: 0.14765262603759766
# Iteration 373
# Iteration time: 0.1438279151916504
# Iteration 374
# Iteration time: 0.16154766082763672
# Iteration 375
# Iteration time: 0.14826631546020508
# Iteration 376
# Iteration time: 0.15964698791503906
# Iteration 377
# Iteration time: 0.15065479278564453
# Iteration 378
# Iteration time: 0.15231013298034668
# Iteration 379
# Iteration time: 0.16181254386901855
# Iteration 380
# Iteration time: 0.16921281814575195
# Iteration 381
# Iteration time: 0.16523361206054688
# Iteration 382
# Iteration time: 0.17245912551879883
# Iteration 383
# Iteration time: 0.16311264038085938
# Iteration 384
# Iteration time: 0.158158540725708
# Iteration 385
# Iteration time: 0.1478567123413086
# Iteration 386
# Iteration time: 0.16448187828063965
# Iteration 387
# Iteration time: 0.14142894744873047
# Iteration 388
# Iteration time: 0.1527409553527832
# Iteration 389
# Iteration time: 0.14484071731567383
# Iteration 390
# Iteration time: 0.15272784233093262
# Iteration 391
# Iteration time: 0.1447582244873047
# Iteration 392
# Iteration time: 0.14976978302001953
# Iteration 393
# Iteration time: 0.14551115036010742
# Iteration 394
# Iteration time: 0.15656328201293945
# Iteration 395
# Iteration time: 0.14249897003173828
# Iteration 396
# Iteration time: 0.14990830421447754
# Iteration 397
# Iteration time: 0.15286660194396973
# Iteration 398
# Iteration time: 0.15644121170043945
# Iteration 399
# Iteration time: 0.1465137004852295
# Iteration 400
# Iteration time: 0.15607500076293945
# [-4.97687147e-06  1.58908919e-06  8.54928167e-07  2.82759865e-06
#  -4.60334379e-06  3.67786410e-06  5.95787770e-06  2.68065717e-06
#  -2.10441259e-06 -5.87813748e-06 -4.57626364e-06 -1.17909968e-05
#  -1.28851753e-06 -4.99201999e-06  1.52066967e-06  8.85796446e-07
#   3.00496669e-06 -4.21364453e-06  3.88694782e-06  6.13402665e-06
#   2.50037052e-06 -1.93593830e-06 -5.70103605e-06 -4.40190950e-06
#  -1.16059728e-05 -1.15459004e-06 -5.12838542e-06  1.52865461e-06
#   7.22129439e-07  2.63767348e-06 -4.67082816e-06  3.49749659e-06
#   5.73234951e-06  2.38764213e-06 -1.94318475e-06 -5.92821713e-06
#  -4.12995076e-06 -1.18686265e-05 -1.18288636e-06 -4.86876056e-06
#   1.61648255e-06  7.11055506e-07  2.91492285e-06 -4.39643651e-06
#   3.67728591e-06  5.95158257e-06  2.71312116e-06 -1.79921026e-06
#  -5.64092748e-06 -4.14012061e-06 -1.15534486e-05 -1.10396014e-06
#  -1.70470686e-06 -1.66374823e-06 -1.80533631e-06  4.90704266e-07
#   2.26111793e-06  3.28779812e-07  1.85007322e-06  2.05012841e-06
#   1.53256803e-06  4.86656914e-07 -4.14492201e-07 -9.93412780e-07
#  -1.39429345e-07]
# Iteration 401
# Iteration time: 0.15030574798583984
# Iteration 402
# Iteration time: 0.1505134105682373
# Iteration 403
# Iteration time: 0.13822484016418457
# Iteration 404
# Iteration time: 0.14753389358520508
# Iteration 405
# Iteration time: 0.14484357833862305
# Iteration 406
# Iteration time: 0.15525245666503906
# Iteration 407
# Iteration time: 0.14490532875061035
# Iteration 408
# Iteration time: 0.15960311889648438
# Iteration 409
# Iteration time: 0.16870784759521484
# Iteration 410
# Iteration time: 0.16156482696533203
# Iteration 411
# Iteration time: 0.14969229698181152
# Iteration 412
# Iteration time: 0.17083048820495605
# Iteration 413
# Iteration time: 0.15344667434692383
# Iteration 414
# Iteration time: 0.14696717262268066
# Iteration 415
# Iteration time: 0.1502530574798584
# Iteration 416
# Iteration time: 0.15185928344726562
# Iteration 417
# Iteration time: 0.14568352699279785
# Iteration 418
# Iteration time: 0.1528475284576416
# Iteration 419
# Iteration time: 0.15581798553466797
# Iteration 420
# Iteration time: 0.1631488800048828
# Iteration 421
# Iteration time: 0.14402341842651367
# Iteration 422
# Iteration time: 0.15896105766296387
# Iteration 423
# Iteration time: 0.15248656272888184
# Iteration 424
# Iteration time: 0.1542356014251709
# Iteration 425
# Iteration time: 0.1793067455291748
# Iteration 426
# Iteration time: 0.15278148651123047
# Iteration 427
# Iteration time: 0.15026021003723145
# Iteration 428
# Iteration time: 0.16007113456726074
# Iteration 429
# Iteration time: 0.15672636032104492
# Iteration 430
# Iteration time: 0.15216398239135742
# Iteration 431
# Iteration time: 0.1491556167602539
# Iteration 432
# Iteration time: 0.16627717018127441
# Iteration 433
# Iteration time: 0.15450072288513184
# Iteration 434
# Iteration time: 0.15496039390563965
# Iteration 435
# Iteration time: 0.1723771095275879
# Iteration 436
# Iteration time: 0.17061662673950195
# Iteration 437
# Iteration time: 0.16856169700622559
# Iteration 438
# Iteration time: 0.17739033699035645
# Iteration 439
# Iteration time: 0.17399907112121582
# Iteration 440
# Iteration time: 0.15502452850341797
# Iteration 441
# Iteration time: 0.13849782943725586
# Iteration 442
# Iteration time: 0.14852142333984375
# Iteration 443
# Iteration time: 0.14864516258239746
# Iteration 444
# Iteration time: 0.1497175693511963
# Iteration 445
# Iteration time: 0.14172101020812988
# Iteration 446
# Iteration time: 0.1494581699371338
# Iteration 447
# Iteration time: 0.14537858963012695
# Iteration 448
# Iteration time: 0.14767909049987793
# Iteration 449
# Iteration time: 0.1682436466217041
# Iteration 450
# Iteration time: 0.14670109748840332
# Iteration 451
# Iteration time: 0.1628868579864502
# Iteration 452
# Iteration time: 0.14979267120361328
# Iteration 453
# Iteration time: 0.1467113494873047
# Iteration 454
# Iteration time: 0.15080857276916504
# Iteration 455
# Iteration time: 0.13865971565246582
# Iteration 456
# Iteration time: 0.1573033332824707
# Iteration 457
# Iteration time: 0.14548897743225098
# Iteration 458
# Iteration time: 0.15591955184936523
# Iteration 459
# Iteration time: 0.1493396759033203
# Iteration 460
# Iteration time: 0.15730857849121094
# Iteration 461
# Iteration time: 0.14186477661132812
# Iteration 462
# Iteration time: 0.15323233604431152
# Iteration 463
# Iteration time: 0.15200233459472656
# Iteration 464
# Iteration time: 0.14592695236206055
# Iteration 465
# Iteration time: 0.14481759071350098
# Iteration 466
# Iteration time: 0.15000319480895996
# Iteration 467
# Iteration time: 0.14179110527038574
# Iteration 468
# Iteration time: 0.15157842636108398
# Iteration 469
# Iteration time: 0.14793133735656738
# Iteration 470
# Iteration time: 0.15050387382507324
# Iteration 471
# Iteration time: 0.14294838905334473
# Iteration 472
# Iteration time: 0.15919113159179688
# Iteration 473
# Iteration time: 0.14576363563537598
# Iteration 474
# Iteration time: 0.15544438362121582
# Iteration 475
# Iteration time: 0.16974163055419922
# Iteration 476
# Iteration time: 0.1518385410308838
# Iteration 477
# Iteration time: 0.19027066230773926
# Iteration 478
# Iteration time: 0.15647649765014648
# Iteration 479
# Iteration time: 0.14904141426086426
# Iteration 480
# Iteration time: 0.16035842895507812
# Iteration 481
# Iteration time: 0.14613819122314453
# Iteration 482
# Iteration time: 0.1570451259613037
# Iteration 483
# Iteration time: 0.17029857635498047
# Iteration 484
# Iteration time: 0.17063498497009277
# Iteration 485
# Iteration time: 0.16469860076904297
# Iteration 486
# Iteration time: 0.1678009033203125
# Iteration 487
# Iteration time: 0.15641474723815918
# Iteration 488
# Iteration time: 0.15450572967529297
# Iteration 489
# Iteration time: 0.1454782485961914
# Iteration 490
# Iteration time: 0.1533975601196289
# Iteration 491
# Iteration time: 0.14477133750915527
# Iteration 492
# Iteration time: 0.16144108772277832
# Iteration 493
# Iteration time: 0.16875433921813965
# Iteration 494
# Iteration time: 0.19403481483459473
# Iteration 495
# Iteration time: 0.15545082092285156
# Iteration 496
# Iteration time: 0.15555143356323242
# Iteration 497
# Iteration time: 0.16750001907348633
# Iteration 498
# Iteration time: 0.1500253677368164
# Iteration 499
# Iteration time: 0.14692139625549316
# Iteration 500
# Iteration time: 0.15541458129882812
# [-2.11308250e-06  5.91064016e-07  1.05544276e-06  1.72220280e-06
#  -4.06855552e-07  3.46976436e-06  4.23174894e-06  3.06056390e-06
#   8.01832080e-07 -2.89720705e-06 -1.34116951e-06 -8.27355096e-06
#  -2.99589139e-06 -2.14998435e-06  5.26092972e-07  1.09812633e-06
#   1.90460971e-06 -6.54213288e-08  3.66907770e-06  4.40591178e-06
#   2.86975372e-06  9.56056088e-07 -2.71385422e-06 -1.16215936e-06
#  -8.09343004e-06 -2.88216671e-06 -2.27282742e-06  5.37375399e-07
#   9.21022973e-07  1.53173427e-06 -4.49179062e-07  3.29056093e-06
#   4.00438979e-06  2.77606031e-06  9.77562273e-07 -2.94590577e-06
#  -8.85561771e-07 -8.33474780e-06 -2.89590111e-06 -2.03415107e-06
#   6.31868293e-07  9.17714829e-07  1.80966231e-06 -2.25045792e-07
#   3.45843129e-06  4.22334463e-06  3.09040885e-06  1.11551977e-06
#  -2.65298540e-06 -8.96825274e-07 -8.01870959e-06 -2.83254637e-06
#  -1.89395722e-06 -1.64042297e-06 -1.77756122e-06  6.08702346e-07
#   1.97021548e-06  4.48861022e-07  1.97266638e-06  2.18770109e-06
#   1.44828739e-06  4.23638495e-07 -5.09702456e-07 -1.11619946e-06
#  -3.42506951e-08]
# Iteration 501
# Iteration time: 0.15842509269714355
# Iteration 502
# Iteration time: 0.15991663932800293
# Iteration 503
# Iteration time: 0.14986252784729004
# Iteration 504
# Iteration time: 0.15577101707458496
# Iteration 505
# Iteration time: 0.14738941192626953
# Iteration 506
# Iteration time: 0.156663179397583
# Iteration 507
# Iteration time: 0.1438000202178955
# Iteration 508
# Iteration time: 0.15137338638305664
# Iteration 509
# Iteration time: 0.15168976783752441
# Iteration 510
# Iteration time: 0.14735102653503418
# Iteration 511
# Iteration time: 0.14455819129943848
# Iteration 512
# Iteration time: 0.1514601707458496
# Iteration 513
# Iteration time: 0.14068078994750977
# Iteration 514
# Iteration time: 0.1546008586883545
# Iteration 515
# Iteration time: 0.15168142318725586
# Iteration 516
# Iteration time: 0.1579585075378418
# Iteration 517
# Iteration time: 0.14435148239135742
# Iteration 518
# Iteration time: 0.1604301929473877
# Iteration 519
# Iteration time: 0.15616750717163086
# Iteration 520
# Iteration time: 0.15623164176940918
# Iteration 521
# Iteration time: 0.15148091316223145
# Iteration 522
# Iteration time: 0.15603327751159668
# Iteration 523
# Iteration time: 0.1573619842529297
# Iteration 524
# Iteration time: 0.15271735191345215
# Iteration 525
# Iteration time: 0.15004944801330566
# Iteration 526
# Iteration time: 0.15886592864990234
# Iteration 527
# Iteration time: 0.14978432655334473
# Iteration 528
# Iteration time: 0.15705394744873047
# Iteration 529
# Iteration time: 0.16604852676391602
# Iteration 530
# Iteration time: 0.17412042617797852
# Iteration 531
# Iteration time: 0.17199110984802246
# Iteration 532
# Iteration time: 0.18841099739074707
# Iteration 533
# Iteration time: 0.14754080772399902
# Iteration 534
# Iteration time: 0.1841268539428711
# Iteration 535
# Iteration time: 0.15967130661010742
# Iteration 536
# Iteration time: 0.1586616039276123
# Iteration 537
# Iteration time: 0.1467418670654297
# Iteration 538
# Iteration time: 0.1579267978668213
# Iteration 539
# Iteration time: 0.14436984062194824
# Iteration 540
# Iteration time: 0.1747298240661621
# Iteration 541
# Iteration time: 0.14339470863342285
# Iteration 542
# Iteration time: 0.14865636825561523
# Iteration 543
# Iteration time: 0.14696645736694336
# Iteration 544
# Iteration time: 0.14941811561584473
# Iteration 545
# Iteration time: 0.15010714530944824
# Iteration 546
# Iteration time: 0.1610407829284668
# Iteration 547
# Iteration time: 0.14547157287597656
# Iteration 548
# Iteration time: 0.14692068099975586
# Iteration 549
# Iteration time: 0.14479732513427734
# Iteration 550
# Iteration time: 0.15270757675170898
# Iteration 551
# Iteration time: 0.1476893424987793
# Iteration 552
# Iteration time: 0.15401124954223633
# Iteration 553
# Iteration time: 0.15242242813110352
# Iteration 554
# Iteration time: 0.15043354034423828
# Iteration 555
# Iteration time: 0.15278983116149902
# Iteration 556
# Iteration time: 0.14493632316589355
# Iteration 557
# Iteration time: 0.14298796653747559
# Iteration 558
# Iteration time: 0.16733050346374512
# Iteration 559
# Iteration time: 0.14629173278808594
# Iteration 560
# Iteration time: 0.1577143669128418
# Iteration 561
# Iteration time: 0.14084339141845703
# Iteration 562
# Iteration time: 0.14750313758850098
# Iteration 563
# Iteration time: 0.14687061309814453
# Iteration 564
# Iteration time: 0.15810346603393555
# Iteration 565
# Iteration time: 0.15015816688537598
# Iteration 566
# Iteration time: 0.1541285514831543
# Iteration 567
# Iteration time: 0.14418411254882812
# Iteration 568
# Iteration time: 0.15837645530700684
# Iteration 569
# Iteration time: 0.1588878631591797
# Iteration 570
# Iteration time: 0.15503978729248047
# Iteration 571
# Iteration time: 0.14640426635742188
# Iteration 572
# Iteration time: 0.15331363677978516
# Iteration 573
# Iteration time: 0.14653849601745605
# Iteration 574
# Iteration time: 0.15901422500610352
# Iteration 575
# Iteration time: 0.14951157569885254
# Iteration 576
# Iteration time: 0.14549016952514648
# Iteration 577
# Iteration time: 0.1423478126525879
# Iteration 578
# Iteration time: 0.15419435501098633
# Iteration 579
# Iteration time: 0.15447783470153809
# Iteration 580
# Iteration time: 0.15288829803466797
# Iteration 581
# Iteration time: 0.14638066291809082
# Iteration 582
# Iteration time: 0.1536412239074707
# Iteration 583
# Iteration time: 0.14415431022644043
# Iteration 584
# Iteration time: 0.1500682830810547
# Iteration 585
# Iteration time: 0.1477646827697754
# Iteration 586
# Iteration time: 0.15804171562194824
# Iteration 587
# Iteration time: 0.1529555320739746
# Iteration 588
# Iteration time: 0.15850496292114258
# Iteration 589
# Iteration time: 0.15630006790161133
# Iteration 590
# Iteration time: 0.16651034355163574
# Iteration 591
# Iteration time: 0.1591174602508545
# Iteration 592
# Iteration time: 0.15277695655822754
# Iteration 593
# Iteration time: 0.15298175811767578
# Iteration 594
# Iteration time: 0.15032625198364258
# Iteration 595
# Iteration time: 0.16389060020446777
# Iteration 596
# Iteration time: 0.1516108512878418
# Iteration 597
# Iteration time: 0.14798855781555176
# Iteration 598
# Iteration time: 0.15159320831298828
# Iteration 599
# Iteration time: 0.13909339904785156
# Iteration 600
# Iteration time: 0.1552748680114746
# [ 7.84464859e-07  4.92970187e-07  4.19853667e-07 -4.95600997e-07
#  -1.49385373e-06  9.89912685e-08  2.76032129e-07  5.53701753e-07
#   1.14523779e-07 -9.10818418e-07  1.98562198e-08 -2.61627929e-06
#  -1.17198613e-06  7.46689111e-07  4.10832975e-07  4.40809146e-07
#  -3.25213776e-07 -1.14224376e-06  2.81824438e-07  4.53355703e-07
#   3.38738253e-07  2.43292483e-07 -7.60925438e-07  1.94638069e-07
#  -2.45639720e-06 -1.05490887e-06  6.19392544e-07  4.29602029e-07
#   2.87485136e-07 -6.81161470e-07 -1.53339440e-06 -6.97777480e-08
#   3.88821118e-08  2.80306949e-07  2.80308246e-07 -9.56358051e-07
#   4.58412803e-07 -2.67296863e-06 -1.06822061e-06  8.60632817e-07
#   5.08685272e-07  2.71848396e-07 -4.26260691e-07 -1.31649892e-06
#   8.76641018e-08  2.56511731e-07  5.71478594e-07  3.93830682e-07
#  -6.90534172e-07  4.49622785e-07 -2.37425306e-06 -1.00706800e-06
#  -2.06434415e-06 -1.68890551e-06 -1.73913988e-06  6.61358710e-07
#   1.88939294e-06  6.13693565e-07  2.06030386e-06  2.41434118e-06
#   1.53573129e-06  4.20175422e-07 -5.21235585e-07 -1.24865871e-06
#  -3.09208968e-08]
# Iteration 601
# Iteration time: 0.14806532859802246
# Iteration 602
# Iteration time: 0.15352940559387207
# Iteration 603
# Iteration time: 0.1490776538848877
# Iteration 604
# Iteration time: 0.15432167053222656
# Iteration 605
# Iteration time: 0.15184903144836426
# Iteration 606
# Iteration time: 0.15030455589294434
# Iteration 607
# Iteration time: 0.14691734313964844
# Iteration 608
# Iteration time: 0.14861631393432617
# Iteration 609
# Iteration time: 0.1391298770904541
# Iteration 610
# Iteration time: 0.15094256401062012
# Iteration 611
# Iteration time: 0.14682412147521973
# Iteration 612
# Iteration time: 0.15969491004943848
# Iteration 613
# Iteration time: 0.14506244659423828
# Iteration 614
# Iteration time: 0.1562051773071289
# Iteration 615
# Iteration time: 0.15075302124023438
# Iteration 616
# Iteration time: 0.14891481399536133
# Iteration 617
# Iteration time: 0.15022969245910645
# Iteration 618
# Iteration time: 0.15015554428100586
# Iteration 619
# Iteration time: 0.1461939811706543
# Iteration 620
# Iteration time: 0.15515804290771484
# Iteration 621
# Iteration time: 0.14390778541564941
# Iteration 622
# Iteration time: 0.1544780731201172
# Iteration 623
# Iteration time: 0.16333794593811035
# Iteration 624
# Iteration time: 0.15890121459960938
# Iteration 625
# Iteration time: 0.15267157554626465
# Iteration 626
# Iteration time: 0.15222954750061035
# Iteration 627
# Iteration time: 0.15191650390625
# Iteration 628
# Iteration time: 0.1545705795288086
# Iteration 629
# Iteration time: 0.15295743942260742
# Iteration 630
# Iteration time: 0.15554022789001465
# Iteration 631
# Iteration time: 0.15817975997924805
# Iteration 632
# Iteration time: 0.15695977210998535
# Iteration 633
# Iteration time: 0.1885817050933838
# Iteration 634
# Iteration time: 0.15654706954956055
# Iteration 635
# Iteration time: 0.15215063095092773
# Iteration 636
# Iteration time: 0.14870905876159668
# Iteration 637
# Iteration time: 0.14704251289367676
# Iteration 638
# Iteration time: 0.14985108375549316
# Iteration 639
# Iteration time: 0.14684748649597168
# Iteration 640
# Iteration time: 0.15024375915527344
# Iteration 641
# Iteration time: 0.1501140594482422
# Iteration 642
# Iteration time: 0.14983153343200684
# Iteration 643
# Iteration time: 0.14743828773498535
# Iteration 644
# Iteration time: 0.14520835876464844
# Iteration 645
# Iteration time: 0.14376544952392578
# Iteration 646
# Iteration time: 0.15569591522216797
# Iteration 647
# Iteration time: 0.14717745780944824
# Iteration 648
# Iteration time: 0.1536540985107422
# Iteration 649
# Iteration time: 0.15669727325439453
# Iteration 650
# Iteration time: 0.16683673858642578
# Iteration 651
# Iteration time: 0.15757441520690918
# Iteration 652
# Iteration time: 0.15323400497436523
# Iteration 653
# Iteration time: 0.1528308391571045
# Iteration 654
# Iteration time: 0.14787793159484863
# Iteration 655
# Iteration time: 0.14994406700134277
# Iteration 656
# Iteration time: 0.15635156631469727
# Iteration 657
# Iteration time: 0.15131688117980957
# Iteration 658
# Iteration time: 0.1874861717224121
# Iteration 659
# Iteration time: 0.15601515769958496
# Iteration 660
# Iteration time: 0.15333819389343262
# Iteration 661
# Iteration time: 0.15248775482177734
# Iteration 662
# Iteration time: 0.1572260856628418
# Iteration 663
# Iteration time: 0.1631476879119873
# Iteration 664
# Iteration time: 0.16543173789978027
# Iteration 665
# Iteration time: 0.17781734466552734
# Iteration 666
# Iteration time: 0.16095852851867676
# Iteration 667
# Iteration time: 0.1607978343963623
# Iteration 668
# Iteration time: 0.1606893539428711
# Iteration 669
# Iteration time: 0.14810538291931152
# Iteration 670
# Iteration time: 0.15155720710754395
# Iteration 671
# Iteration time: 0.1724414825439453
# Iteration 672
# Iteration time: 0.16603541374206543
# Iteration 673
# Iteration time: 0.1760704517364502
# Iteration 674
# Iteration time: 0.15198016166687012
# Iteration 675
# Iteration time: 0.14238572120666504
# Iteration 676
# Iteration time: 0.1525266170501709
# Iteration 677
# Iteration time: 0.15680360794067383
# Iteration 678
# Iteration time: 0.17141056060791016
# Iteration 679
# Iteration time: 0.1557457447052002
# Iteration 680
# Iteration time: 0.17748451232910156
# Iteration 681
# Iteration time: 0.1759190559387207
# Iteration 682
# Iteration time: 0.17804336547851562
# Iteration 683
# Iteration time: 0.15267682075500488
# Iteration 684
# Iteration time: 0.15462136268615723
# Iteration 685
# Iteration time: 0.13924336433410645
# Iteration 686
# Iteration time: 0.1562955379486084
# Iteration 687
# Iteration time: 0.14312076568603516
# Iteration 688
# Iteration time: 0.1612992286682129
# Iteration 689
# Iteration time: 0.14930391311645508
# Iteration 690
# Iteration time: 0.1491692066192627
# Iteration 691
# Iteration time: 0.14683747291564941
# Iteration 692
# Iteration time: 0.15002965927124023
# Iteration 693
# Iteration time: 0.16734886169433594
# Iteration 694
# Iteration time: 0.1532137393951416
# Iteration 695
# Iteration time: 0.15370583534240723
# Iteration 696
# Iteration time: 0.1537623405456543
# Iteration 697
# Iteration time: 0.1526036262512207
# Iteration 698
# Iteration time: 0.15695524215698242
# Iteration 699
# Iteration time: 0.1503586769104004
# Iteration 700
# Iteration time: 0.15856313705444336
# [-1.09658131e-08  9.87627669e-07 -3.83181778e-07  1.21953854e-06
#  -3.49135199e-07 -3.17199770e-07  1.64018097e-06 -4.53461077e-07
#  -1.49571826e-06 -9.46386649e-07 -1.84890062e-06 -1.41662312e-06
#  -1.20005655e-06 -4.08164169e-08  9.12431219e-07 -3.53495963e-07
#   1.39074906e-06 -4.28995861e-09 -1.24422638e-07  1.81073314e-06
#  -6.68415815e-07 -1.36554563e-06 -7.97170745e-07 -1.67573293e-06
#  -1.25202833e-06 -1.08746780e-06 -1.77576062e-07  9.24069937e-07
#  -5.20549872e-07  1.03575918e-06 -3.86162725e-07 -4.90467905e-07
#   1.41037434e-06 -7.25589203e-07 -1.33092232e-06 -9.94069790e-07
#  -1.41764265e-06 -1.47446407e-06 -1.10134229e-06  7.13044699e-08
#   1.00945405e-06 -5.27682090e-07  1.29181750e-06 -1.74490935e-07
#  -3.24831277e-07  1.62327570e-06 -4.34392959e-07 -1.21444198e-06
#  -7.26750745e-07 -1.42648155e-06 -1.17185742e-06 -1.04490712e-06
#  -2.05595287e-06 -1.68344642e-06 -1.66816277e-06  6.58655057e-07
#   1.89504626e-06  6.89281522e-07  2.07074626e-06  2.29071432e-06
#   1.58409075e-06  4.52431842e-07 -3.20949126e-07 -1.24506764e-06
#  -8.90281597e-08]
# Iteration 701
# Iteration time: 0.14794516563415527
# Iteration 702
# Iteration time: 0.1536240577697754
# Iteration 703
# Iteration time: 0.14678168296813965
# Iteration 704
# Iteration time: 0.15898895263671875
# Iteration 705
# Iteration time: 0.14532017707824707
# Iteration 706
# Iteration time: 0.1557469367980957
# Iteration 707
# Iteration time: 0.15191125869750977
# Iteration 708
# Iteration time: 0.16926264762878418
# Iteration 709
# Iteration time: 0.15394377708435059
# Iteration 710
# Iteration time: 0.1490178108215332
# Iteration 711
# Iteration time: 0.1457223892211914
# Iteration 712
# Iteration time: 0.15594911575317383
# Iteration 713
# Iteration time: 0.14669156074523926
# Iteration 714
# Iteration time: 0.15575790405273438
# Iteration 715
# Iteration time: 0.1413288116455078
# Iteration 716
# Iteration time: 0.15528035163879395
# Iteration 717
# Iteration time: 0.15326952934265137
# Iteration 718
# Iteration time: 0.14903712272644043
# Iteration 719
# Iteration time: 0.1591644287109375
# Iteration 720
# Iteration time: 0.17702269554138184
# Iteration 721
# Iteration time: 0.15393376350402832
# Iteration 722
# Iteration time: 0.14683055877685547
# Iteration 723
# Iteration time: 0.14545893669128418
# Iteration 724
# Iteration time: 0.1591653823852539
# Iteration 725
# Iteration time: 0.14218735694885254
# Iteration 726
# Iteration time: 0.15822982788085938
# Iteration 727
# Iteration time: 0.15098834037780762
# Iteration 728
# Iteration time: 0.15982317924499512
# Iteration 729
# Iteration time: 0.13968801498413086
# Iteration 730
# Iteration time: 0.16230344772338867
# Iteration 731
# Iteration time: 0.1425490379333496
# Iteration 732
# Iteration time: 0.1579585075378418
# Iteration 733
# Iteration time: 0.14900445938110352
# Iteration 734
# Iteration time: 0.15280485153198242
# Iteration 735
# Iteration time: 0.14927458763122559
# Iteration 736
# Iteration time: 0.15081048011779785
# Iteration 737
# Iteration time: 0.1513974666595459
# Iteration 738
# Iteration time: 0.16519880294799805
# Iteration 739
# Iteration time: 0.18735885620117188
# Iteration 740
# Iteration time: 0.1647486686706543
# Iteration 741
# Iteration time: 0.16522693634033203
# Iteration 742
# Iteration time: 0.1696023941040039
# Iteration 743
# Iteration time: 0.14060449600219727
# Iteration 744
# Iteration time: 0.14950346946716309
# Iteration 745
# Iteration time: 0.15642905235290527
# Iteration 746
# Iteration time: 0.15381574630737305
# Iteration 747
# Iteration time: 0.15483641624450684
# Iteration 748
# Iteration time: 0.15112900733947754
# Iteration 749
# Iteration time: 0.14333605766296387
# Iteration 750
# Iteration time: 0.1464235782623291
# Iteration 751
# Iteration time: 0.14294743537902832
# Iteration 752
# Iteration time: 0.15232610702514648
# Iteration 753
# Iteration time: 0.1420440673828125
# Iteration 754
# Iteration time: 0.15316200256347656
# Iteration 755
# Iteration time: 0.1449451446533203
# Iteration 756
# Iteration time: 0.14878273010253906
# Iteration 757
# Iteration time: 0.14719939231872559
# Iteration 758
# Iteration time: 0.16489434242248535
# Iteration 759
# Iteration time: 0.14875411987304688
# Iteration 760
# Iteration time: 0.15300965309143066
# Iteration 761
# Iteration time: 0.1455841064453125
# Iteration 762
# Iteration time: 0.14609432220458984
# Iteration 763
# Iteration time: 0.1408693790435791
# Iteration 764
# Iteration time: 0.1517469882965088
# Iteration 765
# Iteration time: 0.15108251571655273
# Iteration 766
# Iteration time: 0.15470361709594727
# Iteration 767
# Iteration time: 0.15742254257202148
# Iteration 768
# Iteration time: 0.15539288520812988
# Iteration 769
# Iteration time: 0.1506209373474121
# Iteration 770
# Iteration time: 0.15082502365112305
# Iteration 771
# Iteration time: 0.15060687065124512
# Iteration 772
# Iteration time: 0.1640946865081787
# Iteration 773
# Iteration time: 0.15001344680786133
# Iteration 774
# Iteration time: 0.17980575561523438
# Iteration 775
# Iteration time: 0.17601561546325684
# Iteration 776
# Iteration time: 0.18018817901611328
# Iteration 777
# Iteration time: 0.17046070098876953
# Iteration 778
# Iteration time: 0.15513205528259277
# Iteration 779
# Iteration time: 0.15608477592468262
# Iteration 780
# Iteration time: 0.1523914337158203
# Iteration 781
# Iteration time: 0.15126824378967285
# Iteration 782
# Iteration time: 0.1665210723876953
# Iteration 783
# Iteration time: 0.16733241081237793
# Iteration 784
# Iteration time: 0.1762702465057373
# Iteration 785
# Iteration time: 0.14667153358459473
# Iteration 786
# Iteration time: 0.1523890495300293
# Iteration 787
# Iteration time: 0.15078067779541016
# Iteration 788
# Iteration time: 0.1467139720916748
# Iteration 789
# Iteration time: 0.14154624938964844
# Iteration 790
# Iteration time: 0.14855408668518066
# Iteration 791
# Iteration time: 0.13973474502563477
# Iteration 792
# Iteration time: 0.16596031188964844
# Iteration 793
# Iteration time: 0.15015697479248047
# Iteration 794
# Iteration time: 0.14766907691955566
# Iteration 795
# Iteration time: 0.1401815414428711
# Iteration 796
# Iteration time: 0.14954352378845215
# Iteration 797
# Iteration time: 0.14247679710388184
# Iteration 798
# Iteration time: 0.15226984024047852
# Iteration 799
# Iteration time: 0.14993619918823242
# Iteration 800
# Iteration time: 0.14625906944274902
# [ 1.61819472e-07 -4.40601227e-08  1.03433443e-07 -2.83236986e-07
#  -3.90769546e-07 -5.54774289e-08  8.52448228e-08  1.45425048e-07
#  -1.83434565e-08 -3.57407309e-07 -1.87597500e-07 -8.87877238e-07
#  -8.14858629e-07  1.25381582e-07 -1.22311683e-07  1.24938747e-07
#  -1.07746541e-07 -3.92106045e-08  1.31967752e-07  2.63946214e-07
#  -7.17079232e-08  1.11270474e-07 -2.09080962e-07 -1.48245789e-08
#  -7.22309601e-07 -6.99717706e-07 -5.46990009e-09 -1.08199682e-07
#  -3.18951798e-08 -4.71283879e-07 -4.31058247e-07 -2.24853022e-07
#  -1.53858521e-07 -1.25307587e-07  1.49456177e-07 -4.03329935e-07
#   2.50985160e-07 -9.42835769e-07 -7.13093881e-07  2.36903325e-07
#  -2.59525486e-08 -4.66776129e-08 -2.11339316e-07 -2.12051258e-07
#  -6.51786713e-08  6.61403909e-08  1.63741205e-07  2.65853057e-07
#  -1.36800377e-07  2.42072300e-07 -6.40035264e-07 -6.54145234e-07
#  -2.07950930e-06 -1.68065650e-06 -1.68327006e-06  6.76223743e-07
#   1.87907658e-06  6.93692206e-07  2.09572844e-06  2.29202247e-06
#   1.56510754e-06  4.61170091e-07 -4.94776793e-07 -1.24041065e-06
#  -9.32232478e-08]
# Iteration 801
# Iteration time: 0.14145851135253906
# Iteration 802
# Iteration time: 0.1771867275238037
# Iteration 803
# Iteration time: 0.16895031929016113
# Iteration 804
# Iteration time: 0.15827393531799316
# Iteration 805
# Iteration time: 0.16973471641540527
# Iteration 806
# Iteration time: 0.14927315711975098
# Iteration 807
# Iteration time: 0.16338014602661133
# Iteration 808
# Iteration time: 0.1589508056640625
# Iteration 809
# Iteration time: 0.1457233428955078
# Iteration 810
# Iteration time: 0.14773964881896973
# Iteration 811
# Iteration time: 0.15356993675231934
# Iteration 812
# Iteration time: 0.15601086616516113
# Iteration 813
# Iteration time: 0.14942002296447754
# Iteration 814
# Iteration time: 0.15623736381530762
# Iteration 815
# Iteration time: 0.1495964527130127
# Iteration 816
# Iteration time: 0.1488037109375
# Iteration 817
# Iteration time: 0.14498686790466309
# Iteration 818
# Iteration time: 0.15314769744873047
# Iteration 819
# Iteration time: 0.1461198329925537
# Iteration 820
# Iteration time: 0.15324091911315918
# Iteration 821
# Iteration time: 0.14858365058898926
# Iteration 822
# Iteration time: 0.15651726722717285
# Iteration 823
# Iteration time: 0.14974570274353027
# Iteration 824
# Iteration time: 0.16219329833984375
# Iteration 825
# Iteration time: 0.15912580490112305
# Iteration 826
# Iteration time: 0.1699666976928711
# Iteration 827
# Iteration time: 0.15873360633850098
# Iteration 828
# Iteration time: 0.14991283416748047
# Iteration 829
# Iteration time: 0.14435911178588867
# Iteration 830
# Iteration time: 0.15153264999389648
# Iteration 831
# Iteration time: 0.15028071403503418
# Iteration 832
# Iteration time: 0.15632128715515137
# Iteration 833
# Iteration time: 0.14850735664367676
# Iteration 834
# Iteration time: 0.15209174156188965
# Iteration 835
# Iteration time: 0.14248371124267578
# Iteration 836
# Iteration time: 0.14955353736877441
# Iteration 837
# Iteration time: 0.1483302116394043
# Iteration 838
# Iteration time: 0.15700244903564453
# Iteration 839
# Iteration time: 0.14609336853027344
# Iteration 840
# Iteration time: 0.16469693183898926
# Iteration 841
# Iteration time: 0.14868736267089844
# Iteration 842
# Iteration time: 0.16733360290527344
# Iteration 843
# Iteration time: 0.15381240844726562
# Iteration 844
# Iteration time: 0.16338586807250977
# Iteration 845
# Iteration time: 0.16643404960632324
# Iteration 846
# Iteration time: 0.17154550552368164
# Iteration 847
# Iteration time: 0.15446996688842773
# Iteration 848
# Iteration time: 0.1797807216644287
# Iteration 849
# Iteration time: 0.15447092056274414
# Iteration 850
# Iteration time: 0.15232348442077637
# Iteration 851
# Iteration time: 0.14493727684020996
# Iteration 852
# Iteration time: 0.17732715606689453
# Iteration 853
# Iteration time: 0.15714263916015625
# Iteration 854
# Iteration time: 0.15088272094726562
# Iteration 855
# Iteration time: 0.15165996551513672
# Iteration 856
# Iteration time: 0.15633773803710938
# Iteration 857
# Iteration time: 0.1516115665435791
# Iteration 858
# Iteration time: 0.14769864082336426
# Iteration 859
# Iteration time: 0.1526505947113037
# Iteration 860
# Iteration time: 0.15460753440856934
# Iteration 861
# Iteration time: 0.19923877716064453
# Iteration 862
# Iteration time: 0.184312105178833
# Iteration 863
# Iteration time: 0.16093063354492188
# Iteration 864
# Iteration time: 0.20229506492614746
# Iteration 865
# Iteration time: 0.2104651927947998
# Iteration 866
# Iteration time: 0.16242671012878418
# Iteration 867
# Iteration time: 0.15232539176940918
# Iteration 868
# Iteration time: 0.1839454174041748
# Iteration 869
# Iteration time: 0.1802835464477539
# Iteration 870
# Iteration time: 0.2028195858001709
# Iteration 871
# Iteration time: 0.15661859512329102
# Iteration 872
# Iteration time: 0.14658689498901367
# Iteration 873
# Iteration time: 0.14270401000976562
# Iteration 874
# Iteration time: 0.14687037467956543
# Iteration 875
# Iteration time: 0.13679718971252441
# Iteration 876
# Iteration time: 0.13547515869140625
# Iteration 877
# Iteration time: 0.13814043998718262
# Iteration 878
# Iteration time: 0.14278221130371094
# Iteration 879
# Iteration time: 0.14571809768676758
# Iteration 880
# Iteration time: 0.14680933952331543
# Iteration 881
# Iteration time: 0.14698505401611328
# Iteration 882
# Iteration time: 0.15247654914855957
# Iteration 883
# Iteration time: 0.13956594467163086
# Iteration 884
# Iteration time: 0.14421319961547852
# Iteration 885
# Iteration time: 0.14304637908935547
# Iteration 886
# Iteration time: 0.1417090892791748
# Iteration 887
# Iteration time: 0.14647316932678223
# Iteration 888
# Iteration time: 0.14900732040405273
# Iteration 889
# Iteration time: 0.1440587043762207
# Iteration 890
# Iteration time: 0.1770474910736084
# Iteration 891
# Iteration time: 0.1861412525177002
# Iteration 892
# Iteration time: 0.13829398155212402
# Iteration 893
# Iteration time: 0.14004063606262207
# Iteration 894
# Iteration time: 0.14411115646362305
# Iteration 895
# Iteration time: 0.14305543899536133
# Iteration 896
# Iteration time: 0.14586830139160156
# Iteration 897
# Iteration time: 0.14705538749694824
# Iteration 898
# Iteration time: 0.16755008697509766
# Iteration 899
# Iteration time: 0.18154239654541016
# Iteration 900
# Iteration time: 0.17053771018981934
# [ 1.29710322e-07  1.53358194e-07  2.99737351e-07  4.72486867e-08
#  -2.48532576e-07  1.63386979e-07  1.63355159e-07  6.02942620e-08
#  -2.70315969e-07 -3.10614578e-07 -3.75975588e-07 -3.90474593e-07
#  -3.56817846e-08  9.46633776e-08  7.55169722e-08  3.20341730e-07
#   2.22010172e-07  1.02967455e-07  3.49526108e-07  3.41478408e-07
#  -1.57569808e-07 -1.41735548e-07 -1.63360877e-07 -2.03477409e-07
#  -2.26548593e-07  8.12930132e-08 -3.79549832e-08  8.93442049e-08
#   1.64237257e-07 -1.39815562e-07 -2.90052640e-07 -5.66612357e-09
#  -7.54065788e-08 -2.12195616e-07 -1.03728450e-07 -3.56815058e-07
#   5.91670357e-08 -4.45800229e-07  6.81603378e-08  2.05771904e-07
#   1.71573962e-07  1.49154431e-07  1.18871483e-07 -7.05406968e-08
#   1.53241484e-07  1.44292869e-07  7.63229693e-08  1.16867440e-08
#  -9.09481841e-08  5.06682021e-08 -1.44981399e-07  1.28249338e-07
#  -2.06146035e-06 -1.67195035e-06 -1.64984168e-06  6.75582436e-07
#   1.88258093e-06  7.11947246e-07  2.10010708e-06  2.25641892e-06
#   1.55928547e-06  4.97100851e-07 -4.81690469e-07 -1.22938302e-06
#  -1.16398828e-07]
# Iteration 901
# Iteration time: 0.2026355266571045
# Iteration 902
# Iteration time: 0.19343090057373047
# Iteration 903
# Iteration time: 0.2013406753540039
# Iteration 904
# Iteration time: 0.16080594062805176
# Iteration 905
# Iteration time: 0.21103906631469727
# Iteration 906
# Iteration time: 0.20340394973754883
# Iteration 907
# Iteration time: 0.16067790985107422
# Iteration 908
# Iteration time: 0.16362810134887695
# Iteration 909
# Iteration time: 0.14141488075256348
# Iteration 910
# Iteration time: 0.1438591480255127
# Iteration 911
# Iteration time: 0.14600014686584473
# Iteration 912
# Iteration time: 0.15640997886657715
# Iteration 913
# Iteration time: 0.16649651527404785
# Iteration 914
# Iteration time: 0.14453554153442383
# Iteration 915
# Iteration time: 0.14061236381530762
# Iteration 916
# Iteration time: 0.1356813907623291
# Iteration 917
# Iteration time: 0.14197492599487305
# Iteration 918
# Iteration time: 0.15076565742492676
# Iteration 919
# Iteration time: 0.14380145072937012
# Iteration 920
# Iteration time: 0.1784205436706543
# Iteration 921
# Iteration time: 0.13949990272521973
# Iteration 922
# Iteration time: 0.1392505168914795
# Iteration 923
# Iteration time: 0.14619779586791992
# Iteration 924
# Iteration time: 0.1451406478881836
# Iteration 925
# Iteration time: 0.15121889114379883
# Iteration 926
# Iteration time: 0.15459370613098145
# Iteration 927
# Iteration time: 0.16338467597961426
# Iteration 928
# Iteration time: 0.14873576164245605
# Iteration 929
# Iteration time: 0.1419992446899414
# Iteration 930
# Iteration time: 0.1661388874053955
# Iteration 931
# Iteration time: 0.16507816314697266
# Iteration 932
# Iteration time: 0.16098260879516602
# Iteration 933
# Iteration time: 0.14095544815063477
# Iteration 934
# Iteration time: 0.16671991348266602
# Iteration 935
# Iteration time: 0.1523139476776123
# Iteration 936
# Iteration time: 0.14229655265808105
# Iteration 937
# Iteration time: 0.1452491283416748
# Iteration 938
# Iteration time: 0.15091538429260254
# Iteration 939
# Iteration time: 0.14523959159851074
# Iteration 940
# Iteration time: 0.14196419715881348
# Iteration 941
# Iteration time: 0.15085816383361816
# Iteration 942
# Iteration time: 0.14635348320007324
# Iteration 943
# Iteration time: 0.14223194122314453
# Iteration 944
# Iteration time: 0.15612196922302246
# Iteration 945
# Iteration time: 0.1518878936767578
# Iteration 946
# Iteration time: 0.14796853065490723
# Iteration 947
# Iteration time: 0.1504209041595459
# Iteration 948
# Iteration time: 0.14309978485107422
# Iteration 949
# Iteration time: 0.1456916332244873
# Iteration 950
# Iteration time: 0.18330860137939453
# Iteration 951
# Iteration time: 0.1564483642578125
# Iteration 952
# Iteration time: 0.14496469497680664
# Iteration 953
# Iteration time: 0.14575886726379395
# Iteration 954
# Iteration time: 0.14928245544433594
# Iteration 955
# Iteration time: 0.1468644142150879
# Iteration 956
# Iteration time: 0.15017461776733398
# Iteration 957
# Iteration time: 0.14944839477539062
# Iteration 958
# Iteration time: 0.16882872581481934
# Iteration 959
# Iteration time: 0.17202520370483398
# Iteration 960
# Iteration time: 0.17645812034606934
# Iteration 961
# Iteration time: 0.2039322853088379
# Iteration 962
# Iteration time: 0.1795792579650879
# Iteration 963
# Iteration time: 0.19369864463806152
# Iteration 964
# Iteration time: 0.19750380516052246
# Iteration 965
# Iteration time: 0.19214606285095215
# Iteration 966
# Iteration time: 0.1826932430267334
# Iteration 967
# Iteration time: 0.1758415699005127
# Iteration 968
# Iteration time: 0.21878719329833984
# Iteration 969
# Iteration time: 0.20580387115478516
# Iteration 970
# Iteration time: 0.1846318244934082
# Iteration 971
# Iteration time: 0.18265295028686523
# Iteration 972
# Iteration time: 0.19837403297424316
# Iteration 973
# Iteration time: 0.17661356925964355
# Iteration 974
# Iteration time: 0.1847550868988037
# Iteration 975
# Iteration time: 0.18035221099853516
# Iteration 976
# Iteration time: 0.17167377471923828
# Iteration 977
# Iteration time: 0.17198967933654785
# Iteration 978
# Iteration time: 0.19047856330871582
# Iteration 979
# Iteration time: 0.18390774726867676
# Iteration 980
# Iteration time: 0.18658781051635742
# Iteration 981
# Iteration time: 0.17694807052612305
# Iteration 982
# Iteration time: 0.1923811435699463
# Iteration 983
# Iteration time: 0.18828272819519043
# Iteration 984
# Iteration time: 0.1810169219970703
# Iteration 985
# Iteration time: 0.17953729629516602
# Iteration 986
# Iteration time: 0.18727397918701172
# Iteration 987
# Iteration time: 0.19792652130126953
# Iteration 988
# Iteration time: 0.1902446746826172
# Iteration 989
# Iteration time: 0.18726754188537598
# Iteration 990
# Iteration time: 0.18624186515808105

# %%
# Make the test WF with test_params
os.system("mkdir -p {directory}/results".format(directory=directory))

make_input(test_params,0,directory)
with cwd(directory):
    errors.append(run_HF("test",0))

# %%
# Make trial WF and hpsi with solved coeffs
trial_wf = make_wf(sol.x,train_wfs,sortstates,levels)
trial_hpsi = get_hpsi(test_params,h,nbox,lmax,nmax,sortstates,sortenergies,trial_wf,directory)
# Read in the cheated test
restartfile = directory+'/results/wf_numpy.bin.test'
h,nbox,lmax,nmax,sorts,sorte,test_wf = read_wfs(restartfile)
test_hpsi = get_hpsi(test_params,h,nbox,lmax,nmax,sorts,sorte,test_wf,directory+"/results")
#test_hpsi_2 = compute_hpsi(test_params,h,nbox,lmax,nmax,sortstates,sortenergies,test_wf)

for isospin in range(2):
        for j in range(levels[isospin]):
            i_s = sortstates[isospin,2,j]-1
            i_l = sortstates[isospin,1,j]
            i_n = sortstates[isospin,0,j]-1
            norm = np.dot(h*test_wf[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])
            #print(h*np.dot(test_wf[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:]))
            trial_sp = np.dot(-h*trial_hpsi[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])
            test_sp = np.dot(-h*test_hpsi[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:])
            #test_sp_2 = np.dot(-h*test_hpsi_2[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:])
            print("Trial: {trial} Test: {test} Difference: {diff} Norm: {norm}".format(trial=trial_sp,test=test_sp,diff=(trial_sp-test_sp)/trial_sp,norm=norm))
# Out:
# Trial: -37.435869293841755 Test: -38.162804722479905 Difference: -0.01941815275965107 Norm: 0.9978110834146529
# Trial: -29.001884144191877 Test: -28.923137034976953 Difference: 0.0027152411485890887 Norm: 0.9999061917671817
# Trial: -27.49291584978473 Test: -27.37162368368931 Difference: 0.004411760715310538 Norm: 0.9993039421632697
# Trial: -19.28561243553871 Test: -19.390669596621144 Difference: -0.005447437120992851 Norm: 0.9993857893471696
# Trial: -14.998625887144762 Test: -17.221836164358177 Difference: -0.14822759724401927 Norm: 0.9982826320239142
# Trial: -15.687911815957442 Test: -16.16677210412974 Difference: -0.030524157312333433 Norm: 0.9995556700276471
# Trial: -9.448398235708698 Test: -9.890321021079252 Difference: -0.04677224375454227 Norm: 0.9998253718994868
# Trial: -36.23176688286773 Test: -35.7616227511254 Difference: 0.012976020000963269 Norm: 0.9784271093019821
# Trial: -26.135800892826683 Test: -27.712070332462943 Difference: -0.06031073798350246 Norm: 0.999630440831853
# Trial: -25.72368714303316 Test: -27.053459382655078 Difference: -0.05169446480311685 Norm: 0.9961633040074842
# Trial: -16.483663492880176 Test: -17.48133545293677 Difference: -0.06052489244806044 Norm: 0.9996174756188936
# Trial: -16.8194879334119 Test: -17.082564738249744 Difference: -0.01564118990300783 Norm: 0.9987146400892355
# Trial: -6.459919707794316 Test: -14.034352327809374 Difference: -1.1725273629757365 Norm: -0.13944916175846486

# %%
fig = plt.figure()
ax = plt.axes()

isospin = 1
i_s = 0
i_l = 0
i_n = 1

x = np.linspace(0, 20, 2001)
ax.plot(x[:1000],trial_wf[isospin,i_s,i_l,i_n,:1000],color='black')
for i in range(len(train_wfs)):
    ax.plot(x[:1000],train_wfs[i][isospin,i_s,i_l,i_n,:1000],linestyle=":")
ax.plot(x[:1000],test_wf[isospin,i_s,i_l,i_n,:1000],linestyle='--',color='red')

# %%
fig = plt.figure()
ax = plt.axes()
train_num = len(train_wfs)
tot_levels = sum(levels)
train = 6
for i in range(train_num):
    for isospin in range(1,2):
        for j in range(5,6):
            i_s = sortstates[isospin,2,j]-1
            i_l = sortstates[isospin,1,j]
            i_n = sortstates[isospin,0,j]-1
            ax.plot(x[:1000],train_wfs[i][isospin,i_s,i_l,i_n,:1000])#,linestyle='--',color='red')
            #trial_wf[isospin,i_s,i_l,i_n,:] = trial_wf[isospin,i_s,i_l,i_n,:] \
            #    + train_wfs[i][isospin,i_s,i_l,i_n,:] * coeffs[i*tot_levels + isospin*levels[0] + j]

# %%
# Let's get some stats!

samples = 8
dirs = []
nm_sampleparams = []
sampleparams = []
hf_args = []

sample_args = [] #(coeffs,train_wfs,sortstates,levels,test_params,directory)

train_num = len(train_wfs)

print("Training with {} WFs, each one with {} total states over {} samples".format(train_num,sum(levels),samples))

ak = np.zeros((train_num,sum(levels)))
lam = np.zeros((sum(levels)))
coeffs = np.zeros((train_num*sum(levels) + sum(levels)))
coeffs[0:train_num*sum(levels)] = 0.1
coeffs[train_num*sum(levels):] = 25.0
nm_sampleparams = []
with open('nm_params.json') as f:
    for line in f:
        nm_sampleparams.append(json.loads(line))
for i in range(samples):
    directory = '/mnt/ram/HF.{}'.format(i)
    dirs.append(directory)
    os.system("mkdir -p {directory}".format(directory=directory))
    os.system("cp ../HF/main {directory}/.".format(directory=directory))
    os.system("mkdir -p {directory}/results".format(directory=directory))
    nmparam = nmdefault_params
    nmparam["LASS"] = i*(150 - 30)/samples + 30.0 #random.uniform(30.0,120.0)
    print(nmparam["LASS"])
    nmparam["K"] = 200.0 #i*(150 - 30)/samples + 200.0 #random.uniform(200.0,240.0)
    #nmparam["ASS"] = random.uniform(28.0,30.0)
    #nmparam["RHO"] = random.uniform(0.155,0.165)
    #nmparam["Crdr"][0] = random.uniform(-60.0,-45.0)
    #nmparam["Crdr"][1] = random.uniform(-200.0,-90.0)
    #nmparam = nm_sampleparams[i].copy()
    nm_sampleparams.append(nmparam.copy())
    sampleparams.append(NM_to_t(nmparam))

    sample_args.append((coeffs,train_wfs,sortstates,levels,NM_to_t(nmparam),directory))

    hf_args.append((NM_to_t(nmparam),directory))



#with open('nm_params.json', 'w') as fout:
#    for dict in nm_sampleparams:
#        json.dump(dict, fout)
#        fout.write("\n")
# optimize.root(galerkin, coeffs, args=(train_wfs,sortstates,levels,test_params,directory), method='hybr', options=hybr_dict)
procs = 8
with Pool(procs) as p:
    sampled_out = p.starmap(galerkin_wrapper_min,sample_args)

with Pool(procs) as p:
    p.starmap(hf_wrapper,hf_args)
# Out:
# Training with 4 WFs, each one with 13 total states over 8 samples
# 30.0
# 45.0
# 60.0
# 75.0
# 90.0
# 105.0
# 120.0
# 135.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4253/3807615025.py in <module>
#      53 procs = 8
#      54 with Pool(procs) as p:
# ---> 55     sampled_out = p.starmap(galerkin_wrapper_min,sample_args)
#      56
#      57 with Pool(procs) as p:
#
# ~/.local/lib/python3.10/site-packages/multiprocess/pool.py in starmap(self, func, iterable, chunksize)
#     370         `func` and (a, b) becomes func(a, b).
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#     374     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/.local/lib/python3.10/site-packages/multiprocess/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/.local/lib/python3.10/site-packages/multiprocess/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     598             signaled = self._flag
#     599             if not signaled:
# --> 600                 signaled = self._cond.wait(timeout)
#     601             return signaled
#     602
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:

# %%
esp_errors = []
defdiffs = []
#optfile = open('train_6_coeffs.bin',mode='wb')
truesp = []
guesssp = []
for i in range(len(sampled_out)):
    #print(galerkin(sampled_out[i].x,train_wfs,sortstates,levels,sampleparams[i],dirs[i]))
    # Make trial WF and hpsi with solved coeffs
    #for cof in sampled_out[i].x:
    #    optfile.write(cof)
    trial_wf = make_wf(sampled_out[i].x,train_wfs,sortstates,levels)
    trial_hpsi = get_hpsi(sampleparams[i],h,nbox,lmax,nmax,sortstates,sortenergies,trial_wf,dirs[i])
    # Read in the cheated test
    restartfile = dirs[i]+'/results/wf_numpy.bin.test'
    h,nbox,lmax,nmax,sorts,sorte,test_wf = read_wfs(restartfile)
    test_hpsi = get_hpsi(sampleparams[i],h,nbox,lmax,nmax,sorts,sorte,test_wf,dirs[i])
    #test_hpsi_2 = compute_hpsi(test_params,h,nbox,lmax,nmax,sortstates,sortenergies,test_wf)
    ediff = 0.0
    defdiff = 0.0
    norms = 0.0
    tsp = []
    gsp = []
    for isospin in range(2):
            for j in range(levels[isospin]):
                i_s = sortstates[isospin,2,j]-1
                i_l = sortstates[isospin,1,j]
                i_n = sortstates[isospin,0,j]-1
                norm = np.dot(h*test_wf[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])
                #print(h*np.dot(test_wf[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:]))
                trial_sp = np.dot(-h*trial_hpsi[isospin,i_s,i_l,i_n,:],trial_wf[isospin,i_s,i_l,i_n,:])
                test_sp = np.dot(-h*test_hpsi[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:])
                tsp.append(test_sp)
                gsp.append(trial_sp)
                ediff += abs((trial_sp-test_sp)/test_sp)
                defdiff += abs((defenergies[isospin*levels[0] + j]-test_sp)/defenergies[isospin*levels[0] + j])
                norms += abs(1.0-norm)
                #test_sp_2 = np.dot(-h*test_hpsi_2[isospin,i_s,i_l,i_n,:],test_wf[isospin,i_s,i_l,i_n,:])
                #print("Trial: {trial} Test: {test} Difference: {diff} Norm: {norm}".format(trial=trial_sp,test=test_sp,diff=(trial_sp-test_sp)/trial_sp,norm=norm))
    truesp.append(tsp)
    guesssp.append(gsp)
    eavg = ediff/(levels[0]+levels[1])
    #print("Average SP E Errors {}".format(eavg))
    diffavg = defdiff/(levels[0]+levels[1])
    #print("Average SP Differences {}".format(diffavg))
    defdiffs.append(diffavg)
    esp_errors.append(eavg)
    #print("Sum of Norm Errors {}".format(norms))
#optfile.close()
print("Total Average S.P. Energy Error: {}".format(sum(esp_errors)/len(esp_errors)))
print("Total Average S.P. Energy Diffs: {}".format(sum(defdiffs)/len(defdiffs)))
# Out:
# Total Average S.P. Energy Error: 0.030989968129643903
# Total Average S.P. Energy Diffs: 0.06547656575335375

# %%
fig = plt.figure()
ax = plt.axes()
Ls=[]
tEs=[]
gEs=[]
for i in range(30):
    #Ls.append(nm_sampleparams[i+500]["LASS"])
    Ls.append(i*(150 - 30)/30 + 30.0)
    tEs.append(guesssp[i][0])
    gEs.append(guesssp[i][1])
print(guesssp[15])
ax.plot(Ls,tEs,linestyle='--',color='black',label="True Energy")
ax.plot(Ls,gEs,linestyle='--',color='red')
ax.legend()
# Out:
# [-39.35516068435661, -27.051176403817454, -25.858254814660558, -18.29301964728102, -17.525858169647936, -14.72430773000307, -9.375359216361604, -36.319825661239896, -28.784793277053424, -28.07881628007538, -18.352375532742272, -17.96335337111941, -13.148576561366642]
